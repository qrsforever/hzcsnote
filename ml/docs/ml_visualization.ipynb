# %% [markdown]
# # 技术层面
#
#
# ## 传统时序模型(销量/利润/流量等预测)
#
# 时间序列可以包含趋势，季节性，周期性和残差等成分
#
# [python 统计库实现](https://github.com/statsmodels/statsmodels)
#
# ### AR模型 (平稳时间序列分析)
#
# ### MA模型 (平稳时间序列分析)
#
# ### ARMA模型 (平稳时间序列分析)
#
# ### 自回归移动平均模型ARIMA (非平稳时间序列分析)
#
# [js 实现](https://github.com/zemlyansky/arima)
#
# > SARIMA (Seasonal ARIMA)
# > SARIMAX (Seasonal ARIMA with exogenous variables)
# > AutoARIMA (ARIMA with automatic parameters)
#
# ### 自回归条件异方差模型ARCH (具有方差波动)
#
# ### GARCH (广义的ARCH)
#
#
# ## 机器学习模型
#
# ### 决策树
#
# ### 随机森林
#
# ### 梯度提升(GB/XGBoost/LightGBM/CatBoost)
#
# ### 线性回归
#
# ### 朴素贝叶斯模型
#
#
# ## 深度学习模型
#
# ### 递归神经网络RNN
#
# ### 长期短期记忆网络LSTM (电商评论情感分析)
#
# ### Seq2Seq (基于概率预测未来需求值的分布或者置信区间)
#
# ### DeepAR (aws) (销量/付费意愿/价格等预测)
#
# 特点: 多步预测, 协变量预测, 概率预测, 多元预测
#
# [pytorch实现1](https://github.com/zhykoties/TimeSeries)
#
# [pytroch实现2](https://github.com/jingw2/demand_forecast)
#
# [pytorch实现3](https://github.com/jdb78/pytorch-forecasting)
#
# ### MQ-RNN
#
# [pytroch实现](https://github.com/jingw2/demand_forecast)
#
# ### Deep Factors Model
#
# [pytroch实现](https://github.com/jingw2/demand_forecast)

# %% [markdown]
# ## 关系图 (特征变量之间的关系)
#
# ### 散点图
#
# ### 线图

# %% [markdown]
# ## 分布图 (特征变量的分布情况)
#
# ### 直方图 (离散频率分布, 主要应用在单变量)
#
# ### 核密度估计图 (连续概率密度)
#
# ### 联合分布图 (主要应用在双变量)
#
# ### 经验(累加)分布图 (某一特征的累计概率, 易看出该特征的分布比例)
#
# ### 成对相关图 (特征两两之间的关系图)
#
# ### 地毯图 (单一描述某特征数据的散列分布)

# %% [markdown]
# ## 分类图(分类数据)
#
# ### 分类散点图 (对某分类特征的不同类别绘制散点图)
#
# ### 分簇散点图 (相比分类散点, 其散列的点不重叠)
#
# ### 箱线图 (方便看到特征变量或者分类类别的分位数及离群点)
#
# ### 小提琴图 (除了能看到分位数/离群点,同时可以方便看到哪个位置的密度高)
#
# ### 条形图 (x:分类, y:数值, 可看到中心趋势/置信区间)
#
# ### 计数图 (分类的直方图)
#
# ### 点图 (两个分类特征的类别之间的变化)
#
# ## 矩阵图
#
# ### 热力图 (多个特征两两的相似度)
#
# ## 其他
#
# ### QQ图/PP图 (判断特征变量是否符合某一分布)

# %% [markdown]
# ## 传统模型
#
# ### 自回归移动平均模型ARIMA (非平稳时间序列分析)
#
# ### AR模型 (平稳时间序列分析)
#
# ### MA模型 (平稳时间序列分析)
#
# ### ARMA模型 (平稳时间序列分析)
#
# ### 自回归条件异方差模型ARCH (具有方差波动)
#
# ### GARCH (广义的ARCH)
#
#
# ## 机器学习模型
#
# ### 决策树
#
# ### 随机森林
#
# ### 梯度提升(GB/XGBoost/LightGBM/CatBoost)
#
# ### 线性回归
#
# ### 朴素贝叶斯模型
#
#
# ## 深度学习模型
#
# ### 递归神经网络RNN
#
# ### 长期短期记忆网络LSTM (电商评论情感分析)
#
# ### Seq2Seq (基于概率预测未来需求值的分布或者置信区间)
#
# ### DeepAR
#
# ### MQ-RNN
#
# ### Deep Factors Model

# %% [markdown]
# # 参考

# %% [markdown]
# - https://www.programmersought.com/article/21235432566/
#
# - https://towardsdatascience.com/data-science-for-e-commerce-with-python-a0a97dd7721d
#
# - https://www.programmersought.com/article/62464906445/
#
# - https://www.programmersought.com/article/52884286979/

# %%
https://blog.csdn.net/qq_40195360/article/details/86605860
    
https://info.cambridgespark.com/latest/carrefour-case-study
    
https://blog.csdn.net/li_gf/article/details/107822493
    
https://www.kdnuggets.com/2019/05/churn-prediction-machine-learning.html
    
https://learnpython.com/blog/python-customer-churn-prediction/
    
    
https://www.jianshu.com/p/db5f6b64ca6b
    
https://wenku.baidu.com/view/0353bbda4228915f804d2b160b4e767f5acf80d3.html
    
https://medium.com/3blades-blog/predicting-conversion-rates-with-bayesian-statistics-8911b4ec9b4a
    
https://cloud.tencent.com/developer/news/457024
    
https://amazonaws-china.com/cn/blogs/china/time-series-prediction-with-deep/
