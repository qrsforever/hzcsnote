# %%
# !ls
# Out:
# bidaf.jsonnet  bidaf_squad.ipynb

# %%
# !allennlp train bidaf.jsonnet -s /notebook/tmp/reading_comprehension
# Out:
# 2019-11-08 07:10:55,070 - INFO - allennlp.common.registrable - instantiating registered subclass relu of <class 'allennlp.nn.activations.Activation'>
# 2019-11-08 07:10:55,072 - INFO - allennlp.common.registrable - instantiating registered subclass relu of <class 'allennlp.nn.activations.Activation'>
# 2019-11-08 07:10:55,072 - INFO - allennlp.common.registrable - instantiating registered subclass relu of <class 'allennlp.nn.activations.Activation'>
# 2019-11-08 07:10:55,073 - INFO - allennlp.common.registrable - instantiating registered subclass relu of <class 'allennlp.nn.activations.Activation'>
# 2019-11-08 07:10:55,228 - INFO - allennlp.common.params - random_seed = 13370
# 2019-11-08 07:10:55,228 - INFO - allennlp.common.params - numpy_seed = 1337
# 2019-11-08 07:10:55,228 - INFO - allennlp.common.params - pytorch_seed = 133
# 2019-11-08 07:10:55,234 - INFO - allennlp.common.checks - Pytorch version: 1.2.0.dev20190805
# ...

# %%
# !allennlp evaluate /notebook/tmp/reading_comprehension/model.tar.gz /datasets/squad/squad-dev-v1.1.json
# Out:
# 2019-11-06 11:54:22,838 - INFO - allennlp.models.archival - loading archive file /data/tmp/nlp/reading_comprehension/model.tar.gz
# 2019-11-06 11:54:22,848 - INFO - allennlp.models.archival - extracting archive file /data/tmp/nlp/reading_comprehension/model.tar.gz to temp dir /tmp/tmpqw3qmqcv
# 2019-11-06 11:54:23,395 - INFO - allennlp.data.vocabulary - Loading token dictionary from /tmp/tmpqw3qmqcv/vocabulary.
# ...

# %%
# !echo '{"passage": "The Matrix is a 1999 science fiction action film written and directed by The Wachowskis, starring Keanu Reeves, Laurence Fishburne, Carrie-Anne Moss, Hugo Weaving, and Joe Pantoliano.", "question": "Who stars in The Matrix?"}' | \
    allennlp predict /notebook/tmp/reading_comprehension/model.tar.gz -
# Out:
# 2019-11-06 12:00:23,753 - INFO - allennlp.models.archival - loading archive file /data/tmp/nlp/reading_comprehension/model.tar.gz
# 2019-11-06 12:00:23,754 - INFO - allennlp.models.archival - extracting archive file /data/tmp/nlp/reading_comprehension/model.tar.gz to temp dir /tmp/tmpkwt4ddt9
# 2019-11-06 12:00:24,284 - INFO - allennlp.common.params - type = default
# 2019-11-06 12:00:24,284 - INFO - allennlp.data.vocabulary - Loading token dictionary from /tmp/tmpkwt4ddt9/vocabulary.
# ...

# %%
from allennlp.predictors.predictor import Predictor
predictor = Predictor.from_path('/notebook/tmp/reading_comprehension/model.tar.gz')
predictor.predict(
  passage="The Matrix is a 1999 science fiction action film written and directed by The Wachowskis, starring Keanu Reeves, Laurence Fishburne, Carrie-Anne Moss, Hugo Weaving, and Joe Pantoliano.",
  question="Who stars in The Matrix?"
)
# Out:
# {'passage_question_attention': [[0.17354846000671387,
#    0.14094777405261993,
#    0.06501829624176025,
#    0.062096256762742996,
#    0.24659715592861176,
#    0.3117920458316803],
#   [0.12772776186466217,
#    0.14390720427036285,
#    0.1560600996017456,
#    0.13946689665317535,
#    0.15208344161510468,
#    0.28075462579727173],
#   [0.18432290852069855,
#    0.12671290338039398,
#    0.06449849158525467,
#    0.08099142462015152,
#    0.2775966227054596,
#    0.26587769389152527],
#   [0.2010292410850525,
#    0.13417738676071167,
#    0.050407879054546356,
#    0.06018635630607605,
#    0.29136577248573303,
#    0.2628334164619446],
#   [0.12044717371463776,
#    0.14388881623744965,
#    0.18692006170749664,
#    0.18136896193027496,
#    0.12496087700128555,
#    0.24241413176059723],
#   [0.1758812814950943,
#    0.13315856456756592,
#    0.08851940929889679,
#    0.09683295339345932,
#    0.2376476377248764,
#    0.26796022057533264],
#   [0.17827871441841125,
# ...
