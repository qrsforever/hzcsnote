# %% [markdown]
# # A Walk Through AllenNLP

# %% [markdown]
# ## Training and Evaluating Models

# %%
import torch
import spacy
import en_core_web_sm

# %%
torch.__version__
# Out:
# '1.1.0'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
spacy.__version__
# Out:
# '2.1.9'

# %%
en_core_web_sm.__version__
# Out:
# '2.1.0'

# %%
# !allennlp train \
    /data/jupyter/allennlp/tutorials/getting_started/walk_through_allennlp/simple_tagger.json \
    --recover --serialization-dir /data/tmp/tutorials/getting_started
# Out:
# 2019-11-06 03:10:27,243 - INFO - pytorch_pretrained_bert.modeling - Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# 2019-11-06 03:10:30,296 - INFO - pytorch_transformers.modeling_bert - Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# 2019-11-06 03:10:30,308 - INFO - pytorch_transformers.modeling_xlnet - Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# 2019-11-06 03:10:31,670 - INFO - allennlp.training.util - Recovering from prior training at /data/tmp/tutorials/getting_started.
# 2019-11-06 03:10:31,709 - INFO - allennlp.common.params - random_seed = 13370
# 2019-11-06 03:10:31,751 - INFO - allennlp.common.params - numpy_seed = 1337
# 2019-11-06 03:10:31,751 - INFO - allennlp.common.params - pytorch_seed = 133
# 2019-11-06 03:10:31,760 - INFO - allennlp.common.checks - Pytorch version: 1.1.0
# ...

# %%
# !allennlp evaluate \
    /data/tmp/tutorials/getting_started/model.tar.gz \
    /data/jupyter/allennlp/datasets/getting-started/sentences.small.test
# Out:
# 2019-11-06 03:11:14,360 - INFO - pytorch_pretrained_bert.modeling - Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# 2019-11-06 03:11:15,681 - INFO - pytorch_transformers.modeling_bert - Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# 2019-11-06 03:11:15,692 - INFO - pytorch_transformers.modeling_xlnet - Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# 2019-11-06 03:11:16,594 - INFO - allennlp.models.archival - loading archive file /data/tmp/tutorials/getting_started/model.tar.gz
# 2019-11-06 03:11:16,603 - INFO - allennlp.models.archival - extracting archive file /data/tmp/tutorials/getting_started/model.tar.gz to temp dir /tmp/tmp80d6a7dd
# 2019-11-06 03:11:16,685 - INFO - allennlp.data.vocabulary - Loading token dictionary from /tmp/tmp80d6a7dd/vocabulary.
# ...

# %%
# !allennlp predict \
    /data/tmp/tutorials/getting_started/model.tar.gz \
    /data/jupyter/allennlp/tutorials/getting_started/walk_through_allennlp/input.txt
# Out:
# 2019-11-06 03:12:33,102 - INFO - pytorch_pretrained_bert.modeling - Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# 2019-11-06 03:12:33,645 - INFO - pytorch_transformers.modeling_bert - Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# 2019-11-06 03:12:33,649 - INFO - pytorch_transformers.modeling_xlnet - Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# 2019-11-06 03:12:34,058 - INFO - allennlp.models.archival - loading archive file /data/tmp/tutorials/getting_started/model.tar.gz
# 2019-11-06 03:12:34,059 - INFO - allennlp.models.archival - extracting archive file /data/tmp/tutorials/getting_started/model.tar.gz to temp dir /tmp/tmpmgal13jj
# 2019-11-06 03:12:34,132 - INFO - allennlp.common.params - type = default
# 2019-11-06 03:12:34,132 - INFO - allennlp.data.vocabulary - Loading token dictionary from /tmp/tmpmgal13jj/vocabulary.
# ...
