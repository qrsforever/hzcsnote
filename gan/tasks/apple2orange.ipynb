# %% [markdown]
# # <div align="center"> CycleGAN: horse2zebra  </div>

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
import time
import os
import base64
import requests
import json
import base64
from io import BytesIO
from PIL import Image
from IPython.display import HTML
from k12libs.utils.nb_easy import k12ai_get_data

# %%
g_host = '116.85.5.40'
g_port = 8119
g_user = '16601548608'
g_uuid = '300'

api = 'k12ai/framework/execute'

# %%
config = {
    'dataroot': '/datasets/apple2orange',
    'checkpoints_dir': '/cache/ckpts',
    'model': 'cycle_gan',
    'netD': 'basic',
    'netG': 'resnet_9blocks',
    'norm': 'instance',
    'init_type': 'normal',
    'init_gain': 0.02,
    'no_dropout': True,
    'dataset_mode': 'unaligned',
    'direction': 'AtoB',
    'num_threads': 8,
    'batch_size': 4,
    'no_flip': True,
    'print_freq': 10,
    'save_latest_freq': 80,
    'continue_train': True,
    'beta1': 0.5,
    'lr': 0.002,
    'lr_policy': 'linear',
    'lr_decay_iters': 10,
    'n_epochs': 10,
    'gan_mode': 'lsgan',
    'results_dir': '/cache/results',
    'num_test': 3,
    'verbose': True,
}

# %%
def post_gan_request(uri, op, user, uuid, params=None):
    if not params:
        params = '{}'
    if isinstance(params, dict):
        params = json.dumps(params)
    data = json.loads('''{
        "token": "123456",
        "op":"%s",
        "user": "%s",
        "service_name": "k12gan",
        "service_uuid": "%s",
        "service_params": %s
    }''' % (op, user, uuid, params))
    api = 'http://%s:%d/%s' % (g_host, g_port, uri)
    res = requests.post(url=api, json=data).text
    key = op.split('.')[0]
    return {
        'req': data,
        'res': json.loads(res),
        'key': f'framework/16601548608/{uuid}/{key}'
    }

# %% [markdown]
# ### 启动训练(train.start)

# %%
res = post_gan_request(api, 'train.start', g_user, g_uuid,  config)
res
# Out:
# {'req': {'token': '123456',
#   'op': 'train.start',
#   'user': '16601548608',
#   'service_name': 'k12gan',
#   'service_uuid': '300',
#   'service_params': {'dataroot': '/datasets/apple2orange',
#    'checkpoints_dir': '/cache/ckpts',
#    'model': 'cycle_gan',
#    'netD': 'basic',
#    'netG': 'resnet_9blocks',
#    'norm': 'instance',
#    'init_type': 'normal',
#    'init_gain': 0.02,
#    'no_dropout': True,
#    'dataset_mode': 'unaligned',
#    'direction': 'AtoB',
#    'num_threads': 8,
#    'batch_size': 4,
#    'no_flip': True,
#    'print_freq': 10,
#    'save_latest_freq': 80,
#    'continue_train': True,
#    'beta1': 0.5,
#    'lr': 0.002,
#    'lr_policy': 'linear',
#    'lr_decay_iters': 10,
#    'n_epochs': 10,
#    'gan_mode': 'lsgan',
#    'results_dir': '/cache/results',
#    'num_test': 3,
#    'verbose': True}},
#  'res': {'code': 100000, 'message': {'en': 'success', 'cn': '成功'}},
#  'key': 'framework/16601548608/300/train'}

# %%
k12ai_get_data(res['key'], 'metrics', num=2, waitcnt=60, rm=True)
# Out:
# [{'key': 'framework/16601548608/300/train/metrics/1611728041650',
#   'value': {'version': '0.1.0',
#    'server': 'localhost:8119',
#    'type': 'metrics',
#    'appId': 'talentai',
#    'token': '123456',
#    'user': '16601548608',
#    'op': 'train.start',
#    'service_name': 'k12gan',
#    'service_uuid': '300',
#    'timestamp': 1611728041650,
#    'datetime': '20210127141401',
#    'data': [{'_id_': '29f8d6abe3f2d9fe',
#      'category': '训练',
#      'type': 'scalar',
#      'data': {'title': '训练_学习率',
#       'payload': {'x': {'label': 'iteration', 'value': 120},
#        'y': [{'label': '学习率', 'value': 0.002}]}}}]}},
#  {'key': 'framework/16601548608/300/train/metrics/1611728041716',
#   'value': {'version': '0.1.0',
#    'server': 'localhost:8119',
#    'type': 'metrics',
#    'appId': 'talentai',
#    'token': '123456',
#    'user': '16601548608',
#    'op': 'train.start',
#    'service_name': 'k12gan',
#    'service_uuid': '300',
#    'timestamp': 1611728041716,
#    'datetime': '20210127141401',
#    'data': [{'_id_': '00e1533091cf39a2',
#      'category': '训练',
#      'type': 'scalar',
#      'data': {'title': '训练_损失',
#       'payload': {'x': {'label': 'iteration', 'value': 120},
#        'y': [{'label': 'D_A', 'value': 0.3342546224594116},
#         {'label': 'G_A', 'value': 0.31725651025772095},
#         {'label': 'cycle_A', 'value': 2.6997921466827393},
#         {'label': 'idt_A', 'value': 3.0034656524658203},
#         {'label': 'D_B', 'value': 0.3993662893772125},
#         {'label': 'G_B', 'value': 0.2687300145626068},
#         {'label': 'cycle_B', 'value': 5.6572771072387695},
#         {'label': 'idt_B', 'value': 1.273111343383789}]}}}]}}]

# %% [markdown]
# ### 停止训练((train.stop)

# %%
post_gan_request(api, 'train.stop', g_user, g_uuid)
# Out:
# {'req': {'token': '123456',
#   'op': 'train.stop',
#   'user': '16601548608',
#   'service_name': 'k12gan',
#   'service_uuid': '200',
#   'service_params': {}},
#  'res': {'code': 100000, 'message': {'en': 'success', 'cn': '成功'}},
#  'key': 'framework/16601548608/200/train'}

# %% [markdown]
# ### 恢复训练(train.resume)

# %%
res = post_gan_request(api, 'train.resume', g_user, g_uuid)
res
# Out:
# {'req': {'token': '123456',
#   'op': 'train.resume',
#   'user': '16601548608',
#   'service_name': 'k12gan',
#   'service_uuid': '200',
#   'service_params': {}},
#  'res': {'code': 100000, 'message': {'en': 'success', 'cn': '成功'}},
#  'key': 'framework/16601548608/200/train'}

# %%
k12ai_get_data(res['key'], 'metrics', num=2, waitcnt=60, rm=True)
# Out:
# [{'key': 'framework/16601548608/200/train/metrics/1611716656263',
#   'value': {'version': '0.1.0',
#    'server': 'localhost:8119',
#    'type': 'metrics',
#    'appId': 'talentai',
#    'token': '123456',
#    'user': '16601548608',
#    'op': 'train.resume',
#    'service_name': 'k12gan',
#    'service_uuid': '200',
#    'timestamp': 1611716656263,
#    'datetime': '20210127110416',
#    'data': [{'_id_': '29f8d6abe3f2d9fe',
#      'category': '训练',
#      'type': 'scalar',
#      'data': {'title': '训练_学习率',
#       'payload': {'x': {'label': 'iteration', 'value': 20},
#        'y': [{'label': '学习率', 'value': 0.002}]}}}]}},
#  {'key': 'framework/16601548608/200/train/metrics/1611716656345',
#   'value': {'version': '0.1.0',
#    'server': 'localhost:8119',
#    'type': 'metrics',
#    'appId': 'talentai',
#    'token': '123456',
#    'user': '16601548608',
#    'op': 'train.resume',
#    'service_name': 'k12gan',
#    'service_uuid': '200',
#    'timestamp': 1611716656345,
#    'datetime': '20210127110416',
#    'data': [{'_id_': '00e1533091cf39a2',
#      'category': '训练',
#      'type': 'scalar',
#      'data': {'title': '训练_损失',
#       'payload': {'x': {'label': 'iteration', 'value': 20},
#        'y': [{'label': 'D_A', 'value': 32.577415466308594},
#         {'label': 'G_A', 'value': 30.45682716369629},
#         {'label': 'cycle_A', 'value': 4.716340065002441},
#         {'label': 'idt_A', 'value': 2.970433235168457},
#         {'label': 'D_B', 'value': 8.564186096191406},
#         {'label': 'G_B', 'value': 10.081008911132812},
#         {'label': 'cycle_B', 'value': 5.865537643432617},
#         {'label': 'idt_B', 'value': 2.367380142211914}]}}}]}}]

# %%
post_gan_request(api, 'train.stop', g_user, g_uuid)
time.sleep(5)

# %% [markdown]
# ### 启动评估(evaluate.start)

# %%
res = post_gan_request(api, 'evaluate.start', g_user, g_uuid, config)
res
# Out:
# {'req': {'token': '123456',
#   'op': 'evaluate.start',
#   'user': '16601548608',
#   'service_name': 'k12gan',
#   'service_uuid': '300',
#   'service_params': {'dataroot': '/datasets/apple2orange',
#    'checkpoints_dir': '/cache/ckpts',
#    'model': 'cycle_gan',
#    'netD': 'basic',
#    'netG': 'resnet_9blocks',
#    'norm': 'instance',
#    'init_type': 'normal',
#    'init_gain': 0.02,
#    'no_dropout': True,
#    'dataset_mode': 'unaligned',
#    'direction': 'AtoB',
#    'num_threads': 8,
#    'batch_size': 4,
#    'no_flip': True,
#    'print_freq': 10,
#    'save_latest_freq': 80,
#    'continue_train': True,
#    'beta1': 0.5,
#    'lr': 0.002,
#    'lr_policy': 'linear',
#    'lr_decay_iters': 10,
#    'n_epochs': 10,
#    'gan_mode': 'lsgan',
#    'results_dir': '/cache/results',
#    'num_test': 3,
#    'verbose': True}},
#  'res': {'code': 100000, 'message': {'en': 'success', 'cn': '成功'}},
#  'key': 'framework/16601548608/300/evaluate'}

# %%
results = {}
data = k12ai_get_data(res['key'], 'metrics', num=6, waitcnt=60, rm=True)
if data is not None:
    for item in data:
        d = item['value']['data'][0]['data']
        title = '_'.join(d['title'].split('_')[1:])
        results[title] = base64.b64decode(d['payload'])
print(len(results))
# Out:
# 4

# %%
keys = list(results.keys())
print(keys)

def img_show(name):
    if name in keys:
        return Image.open(BytesIO(results[name]))
    return None
# Out:
# ['real_A', 'fake_B', 'rec_B', 'rec_A']

# %%
img_show('real_A')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F09F5B719E8>

# %%
img_show('fake_B')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F0A67F656A0>

# %%
img_show('rec_A')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F0A67F65710>

# %%
img_show('real_B')

# %%
img_show('fake_A')

# %%
img_show('rec_B')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F0A67F65940>

# %% [markdown]
# ### 停止评估(evaluate.stop)

# %%
post_gan_request(api, 'evaluate.stop', g_user, g_uuid)
# Out:
# {'req': {'token': '123456',
#   'op': 'evaluate.stop',
#   'user': '16601548608',
#   'service_name': 'k12gan',
#   'service_uuid': '100',
#   'service_params': {}},
#  'res': {'code': 100205,
#   'message': {'en': 'task is not found or not running',
#    'cn': '任务停止错误: 请求的服务不存在或者未启动'}},
#  'key': 'framework/16601548608/100/evaluate'}

# %% [markdown]
# ### 启动预测

# %%
test_pic = '/data/datasets/gan/horse2zebra/testA/n02381460_490.jpg'
img = Image.open(test_pic, mode='r').convert('RGB')
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F5DF16C7AC8>

# %%
with open(test_pic, 'rb') as fr:
    b64str = base64.b64encode(fr.read()).decode()

# %%
predict_key = 'framework/16601548608/1/predict'
config_predict = {}
config_predict['b64_image'] = b64str
res = post_gan_request(api, 'predict.start', '16601548608', '1', config_predict)
res
# Out:
# {'req': {'token': '123456',
#   'op': 'predict.start',
#   'user': '16601548608',
#   'service_name': 'k12gan',
#   'service_uuid': '1',
#   'service_params': {'b64_image': '...'}},
#  'res': {'code': 100000, 'message': {'en': 'success', 'cn': '成功'}},
#  'key': 'framework/16601548608/1/predict'}

# %%
test_results = {}
data = k12ai_get_data(res['key'], 'metrics', num=2, waitcnt=30, rm=True)
if data is not None:
    for item in data:
        d = item['value']['data'][0]['data']
        title = '_'.join(d['title'].split('_')[1:])
        test_results[title] = base64.b64decode(d['payload'])
        
test_keys = list(test_results.keys())
test_keys
# Out:
# ['real', 'fake']

# %%
Image.open(BytesIO(test_results['fake']))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F5DF16C76D8>
