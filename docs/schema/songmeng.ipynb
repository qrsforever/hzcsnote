# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import requests

# %% [markdown]
# # Demo
#
# > ### 1 [GOTO 基本类型节点(`k12ai_basic_type.jsonnet`)](/notebooks/docs/schema/k12ai_basic_type.ipynb)
# >
# > ### 2 [GOTO 复杂类型节点(`k12ai_complex_type.jsonnet`)](/notebooks/docs/schema/k12ai_complext_type.ipynb )
# >
# > ### 3 [GOTO 布局类型节点(`k12ai_layout_type.jsonnet`)](/notebooks/docs/schema/k12ai_layout_type.ipynb)
# >
# > ### 4 [GOTO 综合所有节点(`k12ai_all_type.jsonnet`)](/notebooks/docs/schema/k12ai_all_type.ipynb)
# >
# > ### 5 [GOTO K12AI NLP(`k12ai_nlp.jsonnet`)](/notebooks/nlp/schema/k12nlp_schema.ipynb)
# >
# > ### 6 [GOTO K12AI CV(`k12ai_cv.jsonnet`)](/notebooks/cv/schema/k12cv_schema.ipynb)

# %% [markdown]
# # RestAPI for test json

# %% [markdown]
# ## 1. Get Basic Schema Json

# %%
result = requests.post(
    url='http://116.85.5.40:8119/k12ai/framework/schema', 
    json={'file': 'k12ai_basic_type.jsonnet'}).text
print(result)
# Out:
# {
#    "description": "K12 Data Template Model for Basic Type\n",
#    "objs": [
#       {
#          "_id_": "k12.test.k12bool",
#          "default": true,
#          "name": {
#             "cn": "布尔-1",
#             "en": "Bool1"
#          },
#          "tips": "test int tips, here enter\nlet's us continue another line,\n",
#          "type": "bool"
#       },
#       {
#          "objs": [
#             {
#                "_id_": "k12.test.basic.k12int",
#                "default": 100,
#                "max": 120,
#                "min": 0,
#                "name": {
#                   "cn": "整型-1",
#                   "en": "Int-1"
#                },
#                "tips": "test int tips, here enter\nlet's us continue another line,\n",
#                "type": "int"
#             },
#             {
#                "_id_": "k12.test.basic.k12float",
#                "default": 200,
#                "max": 300,
#                "min": 0,
#                "name": {
# ...

# %% [markdown]
# ## 2. Get Complex Schema Json

# %%
result = requests.post(
    url='http://116.85.5.40:8119/k12ai/framework/schema', 
    json={'file': 'k12ai_complex_type.jsonnet'}).text
print(result)
# Out:
# {
#    "description": "K12 Data Template Model for complex type\n",
#    "objs": [
#       {
#          "name": {
#             "cn": "布尔触发测试",
#             "en": "BoolTriggerTest"
#          },
#          "objs": [
#             {
#                "_id_": "k12.test.k12booltrigger",
#                "default": false,
#                "name": {
#                   "cn": "灯",
#                   "en": "Light"
#                },
#                "objs": [
#                   {
#                      "name": {
#                         "cn": "开灯",
#                         "en": "TurnOn"
#                      },
#                      "trigger": {
#                         "objs": [
#                            {
#                               "_id_": "k12.test.booltrigger.brightness",
#                               "default": 100,
#                               "name": {
#                                  "cn": "亮度",
#                                  "en": "Brightness"
# ...

# %% [markdown]
# ## 3. Get Layout Schema Json

# %%
result = requests.post(
    url='http://116.85.5.40:8119/k12ai/framework/schema', 
    json={'file': 'k12ai_layout_type.jsonnet'}).text
print(result)
# Out:
# {
#    "description": "K12 Data Template Model For Layout\n",
#    "objs": [
#       {
#          "objs": [
#             {
#                "name": {
#                   "cn": "页标签-1",
#                   "en": "tab1"
#                },
#                "objs": [
#                   {
#                      "objs": [
#                         {
#                            "name": {
#                               "cn": "折叠卡-1",
#                               "en": "accordion1"
#                            },
#                            "objs": [
#                               {
#                                  "name": {
#                                     "cn": "导航栏-1",
#                                     "en": "navigation1"
#                                  },
#                                  "objs": [
#                                     {
#                                        "name": {
#                                           "cn": "选项卡-1",
# ...

# %% [markdown]
# ## 4. Get All Type Schema Json

# %%
result = requests.post(
    url='http://116.85.5.40:8119/k12ai/framework/schema', 
    json={'file': 'k12ai_all_type.jsonnet'}).text
print(result)
# Out:
# {
#    "description": "K12 Data Template Model For Layout\n",
#    "objs": [
#       {
#          "objs": [
#             {
#                "name": {
#                   "cn": "页标签-1",
#                   "en": "tab1"
#                },
#                "objs": [
#                   {
#                      "objs": [
#                         {
#                            "name": {
#                               "cn": "折叠卡-1",
#                               "en": "accordion1"
#                            },
#                            "objs": [
#                               {
#                                  "name": {
#                                     "cn": "导航栏-1",
#                                     "en": "navigation1"
#                                  },
#                                  "objs": [
#                                     {
#                                        "name": {
#                                           "cn": "选项卡-1",
# ...

# %% [markdown]
# ## 5. Get NLP Schema Json

# %%
result = requests.post(
    url='http://116.85.5.40:8119/k12ai/framework/schema', 
    json={'file': 'k12ai_nlp.jsonnet'}).text
print(result)
# Out:
# {
#    "objs": [
#       {
#          "objs": [
#             {
#                "name": {
#                   "cn": "Data",
#                   "en": "Data"
#                },
#                "objs": [
#                   {
#                      "objs": [
#                         {
#                            "_id_": "task",
#                            "default": "cls",
#                            "name": {
#                               "cn": "Task",
#                               "en": "Task"
#                            },
#                            "readonly": true,
#                            "type": "string"
#                         },
#                         {
#                            "_id_": "method",
#                            "default": "image_classifier",
#                            "name": {
#                               "cn": "Method",
#                               "en": "Method"
#                            },
# ...

# %% [markdown]
# ## 6. Get CV Schema Json

# %%
result = requests.post(
    url='http://116.85.5.40:8119/k12ai/framework/schema', 
    json={'file': 'k12ai_cv.jsonnet'}).text
print(result)
# Out:
# {
#    "objs": [
#       {
#          "objs": [
#             {
#                "name": {
#                   "cn": "Data",
#                   "en": "Data"
#                },
#                "objs": [
#                   {
#                      "objs": [
#                         {
#                            "_id_": "task",
#                            "default": "cls",
#                            "name": {
#                               "cn": "Task",
#                               "en": "Task"
#                            },
#                            "readonly": true,
#                            "type": "string"
#                         },
#                         {
#                            "_id_": "method",
#                            "default": "image_classifier",
#                            "name": {
#                               "cn": "Method",
#                               "en": "Method"
#                            },
# ...
