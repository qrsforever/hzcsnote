# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import requests

# %% [markdown]
# # Demo
#
# > ### 1 [GOTO 基本类型节点(`k12ai_basic_type.jsonnet`)](/notebooks/docs/schema/k12ai_basic_type.ipynb)
# >
# > ### 2 [GOTO 复杂类型节点(`k12ai_complex_type.jsonnet`)](notebooks/docs/schema/k12ai_complext_type.ipynb)
# >
# > ### 3 [GOTO 布局类型节点(`k12ai_layout_type.jsonnet`)](/notebooks/docs/schema/k12ai_layout_type.ipynb)
# >
# > ### 4 [GOTO 综合所有节点(`k12ai_all_type.jsonnet`)](/notebooks/docs/schema/k12ai_all_type.ipynb)
# >
# > ### 5 [GOTO K12AI NLP(`k12ai_nlp.jsonnet`)](/notebooks/nlp/schema/k12nlp_schema.ipynb)

# %% [markdown]
# # RestAPI for test json

# %% [markdown]
# ## 1. Get Basic Schema Json

# %%
result = requests.post(
    url='http://116.85.5.40:8119/k12ai/framework/schema', 
    json={'file': 'k12ai_basic_type.jsonnet'}).text
print(result)
# Out:
# {
#    "description": "K12 Data Template Model for Basic Type\n",
#    "objs": [
#       {
#          "_id_": "k12.test.k12bool",
#          "default": true,
#          "name": {
#             "cn": "布尔-1",
#             "en": "Bool1"
#          },
#          "type": "bool"
#       },
#       {
#          "objs": [
#             {
#                "_id_": "k12.test.basic.k12int",
#                "default": 100,
#                "max": 120,
#                "min": 0,
#                "name": {
#                   "cn": "整型-1",
#                   "en": "Int-1"
#                },
#                "type": "int"
#             },
#             {
#                "_id_": "k12.test.basic.k12float",
#                "default": 200,
#                "max": 300,
#                "min": 0,
#                "name": {
#                   "cn": "浮点-1",
#                   "en": "Float1"
#                },
#                "type": "float"
#             },
#             {
#                "_id_": "k12.test.basic.k12string",
#                "default": "string",
#                "name": {
#                   "cn": "字符串-1",
#                   "en": "String-1"
#                },
#                "readonly": false,
#                "type": "string"
#             },
#             {
#                "_id_": "k12.test.basic.k12string",
#                "default": "string",
#                "name": {
#                   "cn": "字符串-2",
#                   "en": "String-2"
#                },
#                "readonly": true,
#                "type": "string"
#             },
#             {
#                "_id_": "k12.test.basic.k12stringenum",
#                "default": "item1",
#                "name": {
#                   "cn": "字符串枚举-1",
#                   "en": "StringEnum-1"
#                },
#                "objs": [
#                   {
#                      "name": {
#                         "cn": "Item-1",
#                         "en": "Item-1"
#                      },
#                      "value": "item1"
#                   },
#                   {
#                      "name": {
#                         "cn": "Item-2",
#                         "en": "Item-2"
#                      },
#                      "value": "item2"
#                   }
#                ],
#                "type": "string-enum"
#             },
#             {
#                "_id_": "k12.test.array.k12intarray",
#                "default": [
#                   [
#                      1,
#                      2
#                   ],
#                   [
#                      3,
#                      4
#                   ]
#                ],
#                "name": {
#                   "cn": "整型数组-1",
#                   "en": "IntArray-1"
#                },
#                "type": "int-array"
#             },
#             {
#                "_id_": "k12.test.array.k12floatarray",
#                "default": [
#                   1,
#                   200
#                ],
#                "name": {
#                   "cn": "浮点数组-1",
#                   "en": "FloatArray1"
#                },
#                "type": "float-array"
#             },
#             {
#                "_id_": "k12.test.array.k12stringarray",
#                "default": [
#                   "abc",
#                   "xyz"
#                ],
#                "name": {
#                   "cn": "字符串数组-1",
#                   "en": "StringArray1"
#                },
#                "type": "string-array"
#             }
#          ],
#          "type": "H"
#       },
#       {
#          "objs": [
#             {
#                "_id_": "_js.image.k12.test.image.k12image",
#                "default": "http://116.85.5.40:8084/cv/mnist/imgs/test/00000.jpg",
#                "height": 60,
#                "name": {
#                   "cn": "媒体图片-0",
#                   "en": "MediaImage0"
#                },
#                "type": "image",
#                "width": 60
#             },
#             {
#                "_id_": "_js.image.k12.test.image.k12image",
#                "default": "http://116.85.5.40:8084/cv/mnist/imgs/test/00001.jpg",
#                "height": 60,
#                "name": {
#                   "cn": "媒体图片-1",
#                   "en": "MediaImage1"
#                },
#                "type": "image",
#                "width": 60
#             },
#             {
#                "_id_": "_js.image.k12.test.image.k12image",
#                "default": "http://116.85.5.40:8084/cv/mnist/imgs/test/00002.jpg",
#                "height": 60,
#                "name": {
#                   "cn": "媒体图片-2",
#                   "en": "MediaImage2"
#                },
#                "type": "image",
#                "width": 60
#             },
#             {
#                "_id_": "_js.image.k12.test.image.k12image",
#                "default": "http://116.85.5.40:8084/cv/mnist/imgs/test/00003.jpg",
#                "height": 60,
#                "name": {
#                   "cn": "媒体图片-3",
#                   "en": "MediaImage3"
#                },
#                "type": "image",
#                "width": 60
#             },
#             {
#                "_id_": "_js.image.k12.test.image.k12image",
#                "default": "http://116.85.5.40:8084/cv/mnist/imgs/test/00004.jpg",
#                "height": 60,
#                "name": {
#                   "cn": "媒体图片-4",
#                   "en": "MediaImage4"
#                },
#                "type": "image",
#                "width": 60
#             },
#             {
#                "_id_": "_js.image.k12.test.image.k12image",
#                "default": "http://116.85.5.40:8084/cv/mnist/imgs/test/00005.jpg",
#                "height": 60,
#                "name": {
#                   "cn": "媒体图片-5",
#                   "en": "MediaImage5"
#                },
#                "type": "image",
#                "width": 60
#             },
#             {
#                "_id_": "_js.image.k12.test.image.k12image",
#                "default": "http://116.85.5.40:8084/cv/mnist/imgs/test/00006.jpg",
#                "height": 60,
#                "name": {
#                   "cn": "媒体图片-6",
#                   "en": "MediaImage6"
#                },
#                "type": "image",
#                "width": 60
#             },
#             {
#                "_id_": "_js.image.k12.test.image.k12image",
#                "default": "http://116.85.5.40:8084/cv/mnist/imgs/test/00007.jpg",
#                "height": 60,
#                "name": {
#                   "cn": "媒体图片-7",
#                   "en": "MediaImage7"
#                },
#                "type": "image",
#                "width": 60
#             },
#             {
#                "_id_": "_js.image.k12.test.image.k12image",
#                "default": "http://116.85.5.40:8084/cv/mnist/imgs/test/00008.jpg",
#                "height": 60,
#                "name": {
#                   "cn": "媒体图片-8",
#                   "en": "MediaImage8"
#                },
#                "type": "image",
#                "width": 60
#             },
#             {
#                "_id_": "_js.image.k12.test.image.k12image",
#                "default": "http://116.85.5.40:8084/cv/mnist/imgs/test/00009.jpg",
#                "height": 60,
#                "name": {
#                   "cn": "媒体图片-9",
#                   "en": "MediaImage9"
#                },
#                "type": "image",
#                "width": 60
#             }
#          ],
#          "type": "H"
#       },
#       {
#          "_id_": "_js.text.k12.test.text.k12text",
#          "default": "line-1\nline-2\nline-3\n",
#          "height": 120,
#          "name": {
#             "cn": "文本-1",
#             "en": "Text1"
#          },
#          "type": "text",
#          "width": 300
#       },
#       {
#          "name": {
#             "cn": "调试输出: ",
#             "en": "Debug Output"
#          },
#          "objs": [ ],
#          "type": "output"
#       }
#    ],
#    "type": "page"
# }

# %% [markdown]
# ## 2. Get Complex Schema Json

# %%
result = requests.post(
    url='http://116.85.5.40:8119/k12ai/framework/schema', 
    json={'file': 'k12ai_complex_type.jsonnet'}).text
print(result)
# Out:
# {
#    "description": "K12 Data Template Model for complex type\n",
#    "objs": [
#       {
#          "name": {
#             "cn": "布尔触发测试",
#             "en": "BoolTriggerTest"
#          },
#          "objs": [
#             {
#                "_id_": "k12.test.k12booltrigger",
#                "default": false,
#                "name": {
#                   "cn": "灯",
#                   "en": "Light"
#                },
#                "objs": [
#                   {
#                      "name": {
#                         "cn": "开灯",
#                         "en": "TurnOn"
#                      },
#                      "trigger": {
#                         "objs": [
#                            {
#                               "_id_": "k12.test.booltrigger.brightness",
#                               "default": 100,
#                               "name": {
#                                  "cn": "亮度",
#                                  "en": "Brightness"
#                               },
#                               "type": "int"
#                            },
#                            {
#                               "_id_": "k12.test.booltrigger.colortemp",
#                               "default": 250,
#                               "name": {
#                                  "cn": "色温",
#                                  "en": "ColorTemp"
#                               },
#                               "type": "k12.test.booltrigger.float"
#                            },
#                            {
#                               "_id_": "k12.test.booltrigger.hue",
#                               "default": 105,
#                               "name": {
#                                  "cn": "饱和度",
#                                  "en": "HUE"
#                               },
#                               "type": "float"
#                            }
#                         ]
#                      },
#                      "value": true
#                   },
#                   {
#                      "name": {
#                         "cn": "关灯",
#                         "en": "TurnOff"
#                      },
#                      "trigger": { },
#                      "value": false
#                   }
#                ],
#                "type": "bool-trigger"
#             }
#          ],
#          "type": "object"
#       },
#       {
#          "name": {
#             "cn": "字符串枚举触发测试",
#             "en": "StringEnumTriggerTest"
#          },
#          "objs": [
#             {
#                "_id_": "k12.test.k12stringenum",
#                "default": "hue",
#                "name": {
#                   "cn": "选择灯",
#                   "en": "LightSelect"
#                },
#                "objs": [
#                   {
#                      "name": {
#                         "cn": "飞利浦灯",
#                         "en": "Hue"
#                      },
#                      "trigger": {
#                         "objs": [
#                            {
#                               "_id_": "k12.test.stringenum.hue.brightness",
#                               "default": 100,
#                               "name": {
#                                  "cn": "亮度",
#                                  "en": "Brightness"
#                               },
#                               "type": "int"
#                            },
#                            {
#                               "_id_": "k12.test.stringenum.hue.colortemp",
#                               "default": 250,
#                               "name": {
#                                  "cn": "色温",
#                                  "en": "ColorTemp"
#                               },
#                               "type": "float"
#                            },
#                            {
#                               "_id_": "k12.test.stringenum.hue.hue",
#                               "default": 105,
#                               "name": {
#                                  "cn": "饱和度",
#                                  "en": "HUE"
#                               },
#                               "type": "float"
#                            }
#                         ]
#                      },
#                      "value": "hue"
#                   },
#                   {
#                      "name": {
#                         "cn": "控客灯",
#                         "en": "Konke"
#                      },
#                      "trigger": {
#                         "objs": [
#                            {
#                               "_id_": "k12.test.stringenum.konke.brightness",
#                               "default": 100,
#                               "name": {
#                                  "cn": "亮度",
#                                  "en": "Brightness"
#                               },
#                               "type": "int"
#                            }
#                         ]
#                      },
#                      "value": "konke"
#                   }
#                ],
#                "type": "string-enum-trigger"
#             }
#          ],
#          "type": "object"
#       },
#       {
#          "name": {
#             "cn": "字符串枚举分组触发测试",
#             "en": "StringEnumGroupTriggerTest"
#          },
#          "objs": [
#             {
#                "objs": [
#                   {
#                      "_id_": "_js.k12.test.k12booltrigger.BeiJing",
#                      "default": false,
#                      "name": {
#                         "cn": "评价北京",
#                         "en": "TalkBeiJing"
#                      },
#                      "objs": [
#                         {
#                            "trigger": {
#                               "objs": [
#                                  {
#                                     "_id_": "_js_stringenumgroup.k12.test.BeiJing",
#                                     "default": "k12.test.stringenumgroup.good",
#                                     "name": {
#                                        "cn": "北京",
#                                        "en": "BeiJing"
#                                     },
#                                     "objs": [
#                                        {
#                                           "name": {
#                                              "cn": "良好",
#                                              "en": "Good"
#                                           },
#                                           "value": "k12.test.stringenumgroup.good"
#                                        },
#                                        {
#                                           "name": {
#                                              "cn": "很差",
#                                              "en": "Bad"
#                                           },
#                                           "value": "k12.test.stringenumgroup.bad"
#                                        }
#                                     ],
#                                     "type": "string-enum"
#                                  },
#                                  {
#                                     "_id_": "k12.test.stringenumgroupBeiJing.PM25",
#                                     "default": 400,
#                                     "max": 500,
#                                     "min": 0,
#                                     "name": {
#                                        "cn": "PM2.5",
#                                        "en": "PM2.5"
#                                     },
#                                     "type": "int"
#                                  },
#                                  {
#                                     "_id_": "k12.test.stringenumgroupBeiJing.AQI",
#                                     "default": 10,
#                                     "name": {
#                                        "cn": "AQI",
#                                        "en": "AQI"
#                                     },
#                                     "type": "float"
#                                  },
#                                  {
#                                     "_id_": "k12.test.stringenumgroupBeiJing.Humidity",
#                                     "default": 10,
#                                     "name": {
#                                        "cn": "Humidity",
#                                        "en": "Humidity"
#                                     },
#                                     "type": "float"
#                                  }
#                               ]
#                            },
#                            "value": true
#                         },
#                         {
#                            "name": {
#                               "cn": "关灯",
#                               "en": "TurnOff"
#                            },
#                            "trigger": { },
#                            "value": false
#                         }
#                      ],
#                      "type": "bool-trigger"
#                   },
#                   {
#                      "_id_": "_js.k12.test.k12booltrigger.ShangHai",
#                      "default": false,
#                      "name": {
#                         "cn": "评价上海",
#                         "en": "TalkShangHai"
#                      },
#                      "objs": [
#                         {
#                            "trigger": {
#                               "objs": [
#                                  {
#                                     "_id_": "_js_stringenumgroup.k12.test.ShangHai",
#                                     "default": "k12.test.stringenumgroup.good",
#                                     "name": {
#                                        "cn": "上海",
#                                        "en": "ShangHai"
#                                     },
#                                     "objs": [
#                                        {
#                                           "name": {
#                                              "cn": "良好",
#                                              "en": "Good"
#                                           },
#                                           "value": "k12.test.stringenumgroup.good"
#                                        },
#                                        {
#                                           "name": {
#                                              "cn": "很差",
#                                              "en": "Bad"
#                                           },
#                                           "value": "k12.test.stringenumgroup.bad"
#                                        }
#                                     ],
#                                     "type": "string-enum"
#                                  },
#                                  {
#                                     "_id_": "k12.test.stringenumgroupShangHai.PM25",
#                                     "default": 400,
#                                     "max": 500,
#                                     "min": 0,
#                                     "name": {
#                                        "cn": "PM2.5",
#                                        "en": "PM2.5"
#                                     },
#                                     "type": "int"
#                                  },
#                                  {
#                                     "_id_": "k12.test.stringenumgroupShangHai.AQI",
#                                     "default": 10,
#                                     "name": {
#                                        "cn": "AQI",
#                                        "en": "AQI"
#                                     },
#                                     "type": "float"
#                                  },
#                                  { }
#                               ]
#                            },
#                            "value": true
#                         },
#                         {
#                            "name": {
#                               "cn": "关灯",
#                               "en": "TurnOff"
#                            },
#                            "trigger": { },
#                            "value": false
#                         }
#                      ],
#                      "type": "bool-trigger"
#                   },
#                   {
#                      "_id_": "_js.k12.test.k12booltrigger.ShenZhen",
#                      "default": false,
#                      "name": {
#                         "cn": "评价深圳",
#                         "en": "TalkShenZhen"
#                      },
#                      "objs": [
#                         {
#                            "trigger": {
#                               "objs": [
#                                  {
#                                     "_id_": "_js_stringenumgroup.k12.test.ShenZhen",
#                                     "default": "k12.test.stringenumgroup.good",
#                                     "name": {
#                                        "cn": "深圳",
#                                        "en": "ShenZhen"
#                                     },
#                                     "objs": [
#                                        {
#                                           "name": {
#                                              "cn": "良好",
#                                              "en": "Good"
#                                           },
#                                           "value": "k12.test.stringenumgroup.good"
#                                        },
#                                        {
#                                           "name": {
#                                              "cn": "很差",
#                                              "en": "Bad"
#                                           },
#                                           "value": "k12.test.stringenumgroup.bad"
#                                        }
#                                     ],
#                                     "type": "string-enum"
#                                  },
#                                  {
#                                     "_id_": "k12.test.stringenumgroupShenZhen.PM25",
#                                     "default": 400,
#                                     "max": 500,
#                                     "min": 0,
#                                     "name": {
#                                        "cn": "PM2.5",
#                                        "en": "PM2.5"
#                                     },
#                                     "type": "int"
#                                  },
#                                  {
#                                     "_id_": "k12.test.stringenumgroupShenZhen.AQI",
#                                     "default": 10,
#                                     "name": {
#                                        "cn": "AQI",
#                                        "en": "AQI"
#                                     },
#                                     "type": "float"
#                                  },
#                                  {
#                                     "_id_": "k12.test.stringenumgroupShenZhen.Humidity",
#                                     "default": 10,
#                                     "name": {
#                                        "cn": "Humidity",
#                                        "en": "Humidity"
#                                     },
#                                     "type": "float"
#                                  }
#                               ]
#                            },
#                            "value": true
#                         },
#                         {
#                            "name": {
#                               "cn": "关灯",
#                               "en": "TurnOff"
#                            },
#                            "trigger": { },
#                            "value": false
#                         }
#                      ],
#                      "type": "bool-trigger"
#                   },
#                   {
#                      "_id_": "_js.k12.test.k12booltrigger.TengZhou",
#                      "default": false,
#                      "name": {
#                         "cn": "评价滕州",
#                         "en": "TalkTengZhou"
#                      },
#                      "objs": [
#                         {
#                            "trigger": {
#                               "objs": [
#                                  {
#                                     "_id_": "_js_stringenumgroup.k12.test.TengZhou",
#                                     "default": "k12.test.stringenumgroup.good",
#                                     "name": {
#                                        "cn": "滕州",
#                                        "en": "TengZhou"
#                                     },
#                                     "objs": [
#                                        {
#                                           "name": {
#                                              "cn": "良好",
#                                              "en": "Good"
#                                           },
#                                           "value": "k12.test.stringenumgroup.good"
#                                        },
#                                        {
#                                           "name": {
#                                              "cn": "很差",
#                                              "en": "Bad"
#                                           },
#                                           "value": "k12.test.stringenumgroup.bad"
#                                        }
#                                     ],
#                                     "type": "string-enum"
#                                  },
#                                  {
#                                     "_id_": "k12.test.stringenumgroupTengZhou.PM25",
#                                     "default": 400,
#                                     "max": 500,
#                                     "min": 0,
#                                     "name": {
#                                        "cn": "PM2.5",
#                                        "en": "PM2.5"
#                                     },
#                                     "type": "int"
#                                  },
#                                  {
#                                     "_id_": "k12.test.stringenumgroupTengZhou.AQI",
#                                     "default": 10,
#                                     "name": {
#                                        "cn": "AQI",
#                                        "en": "AQI"
#                                     },
#                                     "type": "float"
#                                  },
#                                  { }
#                               ]
#                            },
#                            "value": true
#                         },
#                         {
#                            "name": {
#                               "cn": "关灯",
#                               "en": "TurnOff"
#                            },
#                            "trigger": { },
#                            "value": false
#                         }
#                      ],
#                      "type": "bool-trigger"
#                   }
#                ],
#                "type": "object"
#             }
#          ],
#          "type": "H"
#       },
#       {
#          "name": {
#             "cn": "调试输出: ",
#             "en": "Debug Output"
#          },
#          "objs": [ ],
#          "type": "output"
#       }
#    ],
#    "type": "page"
# }

# %% [markdown]
# ## 3. Get Layout Schema Json

# %%
result = requests.post(
    url='http://116.85.5.40:8119/k12ai/framework/schema', 
    json={'file': 'k12ai_layout_type.jsonnet'}).text
print(result)
# Out:
# {
#    "description": "K12 Data Template Model For Layout\n",
#    "objs": [
#       {
#          "objs": [
#             {
#                "name": {
#                   "cn": "页标签-1",
#                   "en": "tab1"
#                },
#                "objs": [
#                   {
#                      "objs": [
#                         {
#                            "name": {
#                               "cn": "折叠卡-1",
#                               "en": "accordion1"
#                            },
#                            "objs": [
#                               {
#                                  "name": {
#                                     "cn": "导航栏-1",
#                                     "en": "navigation1"
#                                  },
#                                  "objs": [
#                                     {
#                                        "name": {
#                                           "cn": "选项卡-1",
#                                           "en": "group1"
#                                        },
#                                        "objs": [
#                                           {
#                                              "_id_": "_js.text.a.b.k12text",
#                                              "default": "我的右上角\n\n**有**\n\n粗体黑字的分割标题\n",
#                                              "height": 120,
#                                              "name": {
#                                                 "cn": "文本-1",
#                                                 "en": "Text1"
#                                              },
#                                              "type": "text",
#                                              "width": 300
#                                           }
#                                        ],
#                                        "type": "object"
#                                     },
#                                     {
#                                        "name": {
#                                           "cn": "选项卡-2",
#                                           "en": "group2"
#                                        },
#                                        "objs": [
#                                           {
#                                              "_id_": "_js.text.a.v.k12text",
#                                              "default": "line-1\nline-2\nline-3\n",
#                                              "height": 120,
#                                              "name": {
#                                                 "cn": "文本-2",
#                                                 "en": "Text2"
#                                              },
#                                              "type": "text",
#                                              "width": 300
#                                           }
#                                        ],
#                                        "type": "object"
#                                     }
#                                  ],
#                                  "type": "navigation"
#                               },
#                               {
#                                  "name": {
#                                     "cn": "导航栏-2",
#                                     "en": "navigation2"
#                                  },
#                                  "objs": [
#                                     {
#                                        "name": {
#                                           "cn": "选项卡-3",
#                                           "en": "group3"
#                                        },
#                                        "objs": [
#                                           {
#                                              "_id_": "_js.text.a.m.k12text",
#                                              "default": "我的右上角\n\n**没有**\n\n粗体黑字的分割标题\n",
#                                              "height": 120,
#                                              "name": {
#                                                 "cn": "文本-3",
#                                                 "en": "Text3"
#                                              },
#                                              "type": "text",
#                                              "width": 300
#                                           }
#                                        ],
#                                        "type": "_ignore_"
#                                     }
#                                  ]
#                               }
#                            ]
#                         },
#                         {
#                            "name": {
#                               "cn": "折叠卡-2",
#                               "en": "accordion2"
#                            },
#                            "objs": [
#                               {
#                                  "_id_": "_js.text.a.b.k12text",
#                                  "default": "line-1\nline-2\nline-3\n",
#                                  "height": 120,
#                                  "name": {
#                                     "cn": "文本-4",
#                                     "en": "Text4"
#                                  },
#                                  "type": "text",
#                                  "width": 300
#                               }
#                            ]
#                         },
#                         {
#                            "name": {
#                               "cn": "折叠卡-3",
#                               "en": "accordion3"
#                            },
#                            "objs": [ ]
#                         }
#                      ],
#                      "type": "accordion"
#                   }
#                ]
#             },
#             {
#                "name": {
#                   "cn": "页标签-2",
#                   "en": "tab2"
#                },
#                "objs": [
#                   {
#                      "name": {
#                         "cn": "导航栏-2",
#                         "en": "navigation3"
#                      },
#                      "objs": [
#                         {
#                            "name": {
#                               "cn": "选项卡-1",
#                               "en": "group1"
#                            },
#                            "objs": [
#                               {
#                                  "_id_": "_js.text.a.y.k12text",
#                                  "default": "line-1\nline-2\nline-3\n",
#                                  "height": 120,
#                                  "name": {
#                                     "cn": "文本-5",
#                                     "en": "Text5"
#                                  },
#                                  "type": "text",
#                                  "width": 300
#                               }
#                            ],
#                            "type": "_ignore_"
#                         },
#                         {
#                            "name": {
#                               "cn": "选项卡-2",
#                               "en": "group2"
#                            },
#                            "objs": [ ],
#                            "type": "_ignore_"
#                         }
#                      ],
#                      "type": "navigation"
#                   }
#                ]
#             },
#             {
#                "name": {
#                   "cn": "页标签-3",
#                   "en": "tab3"
#                },
#                "objs": [
#                   {
#                      "objs": [
#                         {
#                            "_id_": "_js.text.a.x.k12text",
#                            "default": "line-1\nline-2\nline-3\n",
#                            "height": 120,
#                            "name": {
#                               "cn": "文本-6",
#                               "en": "Text6"
#                            },
#                            "type": "text",
#                            "width": 300
#                         }
#                      ],
#                      "type": "H"
#                   }
#                ]
#             }
#          ],
#          "type": "tab"
#       },
#       {
#          "name": {
#             "cn": "调试输出: ",
#             "en": "Debug Output"
#          },
#          "objs": [ ],
#          "type": "output"
#       }
#    ],
#    "type": "page"
# }

# %% [markdown]
# ## 4. Get All Type Schema Json

# %%
result = requests.post(
    url='http://116.85.5.40:8119/k12ai/framework/schema', 
    json={'file': 'k12ai_all_type.jsonnet'}).text
print(result)
# Out:
# {
#    "objs": [
#       {
#          "objs": [
#             {
#                "name": {
#                   "cn": "Data",
#                   "en": "Data"
#                },
#                "objs": [
#                   {
#                      "_id_": "_k12.dataset",
#                      "default": "sst",
#                      "name": {
#                         "cn": "Dataset Name",
#                         "en": "Dataset Name"
#                      },
#                      "readonly": true,
#                      "type": "string"
#                   },
#                   {
#                      "objs": [
#                         {
#                            "name": {
#                               "cn": "Reader",
#                               "en": "Reader"
#                            },
#                            "objs": [
#                               {
#                                  "name": {
#                                     "cn": "Phase",
#                                     "en": "Phase"
#                                  },
#                                  "objs": [
#                                     {
#                                        "name": {
#                                           "cn": "Train",
#                                           "en": "Train"
#                                        },
#                                        "objs": [
#                                           {
#                                              "_id_": "dataset_name_reader.type",
#                                              "default": "sst_tokens",
#                                              "name": {
#                                                 "cn": "Type",
#                                                 "en": "Type"
#                                              },
#                                              "objs": [
#                                                 {
#                                                    "name": {
#                                                       "cn": "SST Tokens",
#                                                       "en": "SST Tokens"
#                                                    },
#                                                    "trigger": {
#                                                       "objs": [
#                                                          {
#                                                             "objs": [
#                                                                {
#                                                                   "_id_": "dataset_name_reader.layz",
#                                                                   "default": true,
#                                                                   "name": {
#                                                                      "cn": "lazy",
#                                                                      "en": "lazy"
#                                                                   },
#                                                                   "type": "bool"
#                                                                },
#                                                                {
#                                                                   "_id_": "dataset_name_reader.use_subtrees",
#                                                                   "default": false,
#                                                                   "name": {
#                                                                      "cn": "use subtrees",
#                                                                      "en": "use subtrees"
#                                                                   },
#                                                                   "type": "bool"
#                                                                },
#                                                                {
#                                                                   "_id_": "dataset_name_reader.granularity",
#                                                                   "default": "5-class",
#                                                                   "name": {
#                                                                      "cn": "granularity",
#                                                                      "en": "granularity"
#                                                                   },
#                                                                   "type": "string"
#                                                                }
#                                                             ],
#                                                             "type": "H"
#                                                          },
#                                                          {
#                                                             "_id_": "_k12.token_indexers.single_id",
#                                                             "default": false,
#                                                             "name": {
#                                                                "cn": "single_id",
#                                                                "en": "single_id"
#                                                             },
#                                                             "objs": [
#                                                                {
#                                                                   "trigger": {
#                                                                      "objs": [
#                                                                         {
#                                                                            "objs": [
#                                                                               {
#                                                                                  "_id_": "dataset_name_readertoken_indexers.tokens.type",
#                                                                                  "default": "single_id",
#                                                                                  "name": {
#                                                                                     "cn": "type",
#                                                                                     "en": "type"
#                                                                                  },
#                                                                                  "readonly": true,
#                                                                                  "type": "string"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "dataset_name_readertoken_indexers.tokens.lowercase_tokens",
#                                                                                  "default": false,
#                                                                                  "name": {
#                                                                                     "cn": "lowercase",
#                                                                                     "en": "lowercase"
#                                                                                  },
#                                                                                  "type": "bool"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "dataset_name_readertoken_indexers.tokens.token_min_padding_length",
#                                                                                  "default": 0,
#                                                                                  "name": {
#                                                                                     "cn": "min padding length",
#                                                                                     "en": "min padding length"
#                                                                                  },
#                                                                                  "type": "int"
#                                                                               }
#                                                                            ],
#                                                                            "type": "H"
#                                                                         }
#                                                                      ]
#                                                                   },
#                                                                   "value": true
#                                                                },
#                                                                {
#                                                                   "trigger": { },
#                                                                   "value": false
#                                                                }
#                                                             ],
#                                                             "type": "bool-trigger"
#                                                          }
#                                                       ]
#                                                    },
#                                                    "value": "sst_tokens"
#                                                 }
#                                              ],
#                                              "type": "string-enum-trigger"
#                                           }
#                                        ]
#                                     },
#                                     {
#                                        "name": {
#                                           "cn": "Validation",
#                                           "en": "Validation"
#                                        },
#                                        "objs": [
#                                           {
#                                              "_id_": "_k12.validation_dataset_name_reader.bool",
#                                              "default": false,
#                                              "name": {
#                                                 "cn": "Enable",
#                                                 "en": "Enable"
#                                              },
#                                              "objs": [
#                                                 {
#                                                    "trigger": {
#                                                       "objs": [
#                                                          {
#                                                             "_id_": "validation_dataset_name_reader.type",
#                                                             "default": "sst_tokens",
#                                                             "name": {
#                                                                "cn": "Type",
#                                                                "en": "Type"
#                                                             },
#                                                             "objs": [
#                                                                {
#                                                                   "name": {
#                                                                      "cn": "SST Tokens",
#                                                                      "en": "SST Tokens"
#                                                                   },
#                                                                   "trigger": {
#                                                                      "objs": [
#                                                                         {
#                                                                            "objs": [
#                                                                               {
#                                                                                  "_id_": "validation_dataset_name_reader.layz",
#                                                                                  "default": true,
#                                                                                  "name": {
#                                                                                     "cn": "lazy",
#                                                                                     "en": "lazy"
#                                                                                  },
#                                                                                  "type": "bool"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_dataset_name_reader.use_subtrees",
#                                                                                  "default": false,
#                                                                                  "name": {
#                                                                                     "cn": "use subtrees",
#                                                                                     "en": "use subtrees"
#                                                                                  },
#                                                                                  "type": "bool"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_dataset_name_reader.granularity",
#                                                                                  "default": "5-class",
#                                                                                  "name": {
#                                                                                     "cn": "granularity",
#                                                                                     "en": "granularity"
#                                                                                  },
#                                                                                  "type": "string"
#                                                                               }
#                                                                            ],
#                                                                            "type": "H"
#                                                                         },
#                                                                         {
#                                                                            "_id_": "_k12.token_indexers.single_id",
#                                                                            "default": false,
#                                                                            "name": {
#                                                                               "cn": "single_id",
#                                                                               "en": "single_id"
#                                                                            },
#                                                                            "objs": [
#                                                                               {
#                                                                                  "trigger": {
#                                                                                     "objs": [
#                                                                                        {
#                                                                                           "objs": [
#                                                                                              {
#                                                                                                 "_id_": "validation_dataset_name_readertoken_indexers.tokens.type",
#                                                                                                 "default": "single_id",
#                                                                                                 "name": {
#                                                                                                    "cn": "type",
#                                                                                                    "en": "type"
#                                                                                                 },
#                                                                                                 "readonly": true,
#                                                                                                 "type": "string"
#                                                                                              },
#                                                                                              {
#                                                                                                 "_id_": "validation_dataset_name_readertoken_indexers.tokens.lowercase_tokens",
#                                                                                                 "default": false,
#                                                                                                 "name": {
#                                                                                                    "cn": "lowercase",
#                                                                                                    "en": "lowercase"
#                                                                                                 },
#                                                                                                 "type": "bool"
#                                                                                              },
#                                                                                              {
#                                                                                                 "_id_": "validation_dataset_name_readertoken_indexers.tokens.token_min_padding_length",
#                                                                                                 "default": 0,
#                                                                                                 "name": {
#                                                                                                    "cn": "min padding length",
#                                                                                                    "en": "min padding length"
#                                                                                                 },
#                                                                                                 "type": "int"
#                                                                                              }
#                                                                                           ],
#                                                                                           "type": "H"
#                                                                                        }
#                                                                                     ]
#                                                                                  },
#                                                                                  "value": true
#                                                                               },
#                                                                               {
#                                                                                  "trigger": { },
#                                                                                  "value": false
#                                                                               }
#                                                                            ],
#                                                                            "type": "bool-trigger"
#                                                                         }
#                                                                      ]
#                                                                   },
#                                                                   "value": "sst_tokens"
#                                                                }
#                                                             ],
#                                                             "type": "string-enum-trigger"
#                                                          }
#                                                       ]
#                                                    },
#                                                    "value": true
#                                                 },
#                                                 {
#                                                    "trigger": { },
#                                                    "value": false
#                                                 }
#                                              ],
#                                              "type": "bool-trigger"
#                                           }
#                                        ]
#                                     }
#                                  ],
#                                  "type": "navigation"
#                               }
#                            ]
#                         },
#                         {
#                            "name": {
#                               "cn": "Iterator",
#                               "en": "Iterator"
#                            },
#                            "objs": [
#                               {
#                                  "name": {
#                                     "cn": "Phase",
#                                     "en": "Phase"
#                                  },
#                                  "objs": [
#                                     {
#                                        "name": {
#                                           "cn": "Train",
#                                           "en": "Train"
#                                        },
#                                        "objs": [
#                                           {
#                                              "_id_": "iterator.type",
#                                              "default": "bucket",
#                                              "name": {
#                                                 "cn": "Iterator Type",
#                                                 "en": "Iterator Type"
#                                              },
#                                              "objs": [
#                                                 {
#                                                    "name": {
#                                                       "cn": "bucket",
#                                                       "en": "bucket"
#                                                    },
#                                                    "trigger": {
#                                                       "objs": [
#                                                          {
#                                                             "objs": [
#                                                                {
#                                                                   "_id_": "iterator.batch_size",
#                                                                   "default": 32,
#                                                                   "min": 8,
#                                                                   "name": {
#                                                                      "cn": "batch size",
#                                                                      "en": "batch size"
#                                                                   },
#                                                                   "type": "int"
#                                                                },
#                                                                {
#                                                                   "_id_": "iterator.instances_per_epoch",
#                                                                   "default": 32,
#                                                                   "min": 8,
#                                                                   "name": {
#                                                                      "cn": "instance per epoch",
#                                                                      "en": "instance per epoch"
#                                                                   },
#                                                                   "type": "int"
#                                                                },
#                                                                {
#                                                                   "_id_": "iterator.max_instances_in_memory",
#                                                                   "default": 32,
#                                                                   "min": 8,
#                                                                   "name": {
#                                                                      "cn": "max instance",
#                                                                      "en": "max instance"
#                                                                   },
#                                                                   "type": "int"
#                                                                },
#                                                                {
#                                                                   "_id_": "iterator.cache_instances",
#                                                                   "default": false,
#                                                                   "name": {
#                                                                      "cn": "cache instances",
#                                                                      "en": "cache instances"
#                                                                   },
#                                                                   "type": "bool"
#                                                                },
#                                                                {
#                                                                   "_id_": "iterator.track_epoch",
#                                                                   "default": false,
#                                                                   "name": {
#                                                                      "cn": "track epoch",
#                                                                      "en": "track epoch"
#                                                                   },
#                                                                   "type": "bool"
#                                                                }
#                                                             ],
#                                                             "type": "H"
#                                                          },
#                                                          {
#                                                             "objs": [
#                                                                {
#                                                                   "_id_": "iterator.sorting_keys",
#                                                                   "default": [
#                                                                      [
#                                                                         "tokens",
#                                                                         "num_tokens"
#                                                                      ]
#                                                                   ],
#                                                                   "name": {
#                                                                      "cn": "sorting keys",
#                                                                      "en": "sorting keys"
#                                                                   },
#                                                                   "readonly": true,
#                                                                   "type": "string-array",
#                                                                   "width": 600
#                                                                },
#                                                                {
#                                                                   "_id_": "iterator.padding_noise",
#                                                                   "default": 0.10000000000000001,
#                                                                   "name": {
#                                                                      "cn": "padding noise",
#                                                                      "en": "padding noise"
#                                                                   },
#                                                                   "type": "float"
#                                                                },
#                                                                {
#                                                                   "_id_": "iterator.biggest_batch_first",
#                                                                   "default": false,
#                                                                   "name": {
#                                                                      "cn": "biggest batch first",
#                                                                      "en": "biggest batch first"
#                                                                   },
#                                                                   "type": "bool"
#                                                                },
#                                                                {
#                                                                   "_id_": "iterator.skip_smaller_batches",
#                                                                   "default": false,
#                                                                   "name": {
#                                                                      "cn": "skip smaller batches",
#                                                                      "en": "skip smaller batches"
#                                                                   },
#                                                                   "type": "bool"
#                                                                }
#                                                             ],
#                                                             "type": "H"
#                                                          }
#                                                       ]
#                                                    },
#                                                    "value": "bucket"
#                                                 },
#                                                 {
#                                                    "name": {
#                                                       "cn": "basic",
#                                                       "en": "basic"
#                                                    },
#                                                    "trigger": {
#                                                       "objs": [
#                                                          {
#                                                             "_id_": "iterator.batch_size",
#                                                             "default": 32,
#                                                             "min": 8,
#                                                             "name": {
#                                                                "cn": "batch size",
#                                                                "en": "batch size"
#                                                             },
#                                                             "type": "int"
#                                                          },
#                                                          {
#                                                             "_id_": "iterator.instances_per_epoch",
#                                                             "default": 32,
#                                                             "min": 8,
#                                                             "name": {
#                                                                "cn": "instance per epoch",
#                                                                "en": "instance per epoch"
#                                                             },
#                                                             "type": "int"
#                                                          },
#                                                          {
#                                                             "_id_": "iterator.max_instances_in_memory",
#                                                             "default": 32,
#                                                             "min": 8,
#                                                             "name": {
#                                                                "cn": "max instance",
#                                                                "en": "max instance"
#                                                             },
#                                                             "type": "int"
#                                                          },
#                                                          {
#                                                             "_id_": "iterator.cache_instances",
#                                                             "default": false,
#                                                             "name": {
#                                                                "cn": "cache instances",
#                                                                "en": "cache instances"
#                                                             },
#                                                             "type": "bool"
#                                                          },
#                                                          {
#                                                             "_id_": "iterator.track_epoch",
#                                                             "default": false,
#                                                             "name": {
#                                                                "cn": "track epoch",
#                                                                "en": "track epoch"
#                                                             },
#                                                             "type": "bool"
#                                                          }
#                                                       ],
#                                                       "type": "H"
#                                                    },
#                                                    "value": "basic"
#                                                 }
#                                              ],
#                                              "type": "string-enum-trigger"
#                                           }
#                                        ]
#                                     },
#                                     {
#                                        "name": {
#                                           "cn": "Validation",
#                                           "en": "Validation"
#                                        },
#                                        "objs": [
#                                           {
#                                              "_id_": "_k12.validation_iterator.bool",
#                                              "default": false,
#                                              "name": {
#                                                 "cn": "Enable",
#                                                 "en": "Enable"
#                                              },
#                                              "objs": [
#                                                 {
#                                                    "trigger": {
#                                                       "objs": [
#                                                          {
#                                                             "_id_": "validation_iterator.type",
#                                                             "default": "bucket",
#                                                             "name": {
#                                                                "cn": "Iterator Type",
#                                                                "en": "Iterator Type"
#                                                             },
#                                                             "objs": [
#                                                                {
#                                                                   "name": {
#                                                                      "cn": "bucket",
#                                                                      "en": "bucket"
#                                                                   },
#                                                                   "trigger": {
#                                                                      "objs": [
#                                                                         {
#                                                                            "objs": [
#                                                                               {
#                                                                                  "_id_": "validation_iterator.batch_size",
#                                                                                  "default": 32,
#                                                                                  "min": 8,
#                                                                                  "name": {
#                                                                                     "cn": "batch size",
#                                                                                     "en": "batch size"
#                                                                                  },
#                                                                                  "type": "int"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_iterator.instances_per_epoch",
#                                                                                  "default": 32,
#                                                                                  "min": 8,
#                                                                                  "name": {
#                                                                                     "cn": "instance per epoch",
#                                                                                     "en": "instance per epoch"
#                                                                                  },
#                                                                                  "type": "int"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_iterator.max_instances_in_memory",
#                                                                                  "default": 32,
#                                                                                  "min": 8,
#                                                                                  "name": {
#                                                                                     "cn": "max instance",
#                                                                                     "en": "max instance"
#                                                                                  },
#                                                                                  "type": "int"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_iterator.cache_instances",
#                                                                                  "default": false,
#                                                                                  "name": {
#                                                                                     "cn": "cache instances",
#                                                                                     "en": "cache instances"
#                                                                                  },
#                                                                                  "type": "bool"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_iterator.track_epoch",
#                                                                                  "default": false,
#                                                                                  "name": {
#                                                                                     "cn": "track epoch",
#                                                                                     "en": "track epoch"
#                                                                                  },
#                                                                                  "type": "bool"
#                                                                               }
#                                                                            ],
#                                                                            "type": "H"
#                                                                         },
#                                                                         {
#                                                                            "objs": [
#                                                                               {
#                                                                                  "_id_": "validation_iterator.sorting_keys",
#                                                                                  "default": [
#                                                                                     [
#                                                                                        "tokens",
#                                                                                        "num_tokens"
#                                                                                     ]
#                                                                                  ],
#                                                                                  "name": {
#                                                                                     "cn": "sorting keys",
#                                                                                     "en": "sorting keys"
#                                                                                  },
#                                                                                  "readonly": true,
#                                                                                  "type": "string-array",
#                                                                                  "width": 600
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_iterator.padding_noise",
#                                                                                  "default": 0.10000000000000001,
#                                                                                  "name": {
#                                                                                     "cn": "padding noise",
#                                                                                     "en": "padding noise"
#                                                                                  },
#                                                                                  "type": "float"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_iterator.biggest_batch_first",
#                                                                                  "default": false,
#                                                                                  "name": {
#                                                                                     "cn": "biggest batch first",
#                                                                                     "en": "biggest batch first"
#                                                                                  },
#                                                                                  "type": "bool"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_iterator.skip_smaller_batches",
#                                                                                  "default": false,
#                                                                                  "name": {
#                                                                                     "cn": "skip smaller batches",
#                                                                                     "en": "skip smaller batches"
#                                                                                  },
#                                                                                  "type": "bool"
# ...
#                                                    "en": "Weight Decay"
#                                                 },
#                                                 "type": "float"
#                                              }
#                                           ],
#                                           "type": "H"
#                                        },
#                                        "value": "adam"
#                                     },
#                                     {
#                                        "name": {
#                                           "cn": "sgd",
#                                           "en": "sgd"
#                                        },
#                                        "trigger": {
#                                           "objs": [
#                                              {
#                                                 "_id_": "trainer.optimizer.momentum",
#                                                 "default": 0,
#                                                 "name": {
#                                                    "cn": "Momentum",
#                                                    "en": "Momentum"
#                                                 },
#                                                 "type": "float"
#                                              },
#                                              {
#                                                 "_id_": "trainer.optimizer.lr",
#                                                 "default": 0.001,
#                                                 "name": {
#                                                    "cn": "LR",
#                                                    "en": "LR"
#                                                 },
#                                                 "type": "float"
#                                              },
#                                              {
#                                                 "_id_": "trainer.optimizer.weight_decay",
#                                                 "default": 0,
#                                                 "name": {
#                                                    "cn": "Weight Decay",
#                                                    "en": "Weight Decay"
#                                                 },
#                                                 "type": "float"
#                                              }
#                                           ],
#                                           "type": "H"
#                                        },
#                                        "value": "sgd"
#                                     }
#                                  ],
#                                  "type": "string-enum-trigger"
#                               }
#                            ]
#                         },
#                         {
#                            "name": {
#                               "cn": "LR Scheduler",
#                               "en": "LR Scheduler"
#                            },
#                            "objs": [
#                               {
#                                  "_id_": "_k12.lr_scheduler.bool",
#                                  "name": {
#                                     "cn": "Enable",
#                                     "en": "Enable"
#                                  },
#                                  "objs": [
#                                     {
#                                        "trigger": {
#                                           "objs": [
#                                              {
#                                                 "_id_": "trainer.learning_rate_scheduler.type",
#                                                 "default": "reduce_on_plateau",
#                                                 "name": {
#                                                    "cn": "LR Scheduler Type",
#                                                    "en": "LR Scheduler Type"
#                                                 },
#                                                 "objs": [
#                                                    {
#                                                       "name": {
#                                                          "cn": "ReduceLROnPlateau",
#                                                          "en": "ReduceLROnPlateau"
#                                                       },
#                                                       "trigger": {
#                                                          "objs": [
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.mode",
#                                                                "default": "min",
#                                                                "name": {
#                                                                   "cn": "Mode",
#                                                                   "en": "Mode"
#                                                                },
#                                                                "objs": [
#                                                                   {
#                                                                      "name": {
#                                                                         "cn": "min",
#                                                                         "en": "min"
#                                                                      },
#                                                                      "value": "min"
#                                                                   },
#                                                                   {
#                                                                      "name": {
#                                                                         "cn": "max",
#                                                                         "en": "max"
#                                                                      },
#                                                                      "value": "max"
#                                                                   }
#                                                                ],
#                                                                "type": "string-enum"
#                                                             },
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.factor",
#                                                                "default": 0.10000000000000001,
#                                                                "name": {
#                                                                   "cn": "Factor",
#                                                                   "en": "Factor"
#                                                                },
#                                                                "type": "float"
#                                                             },
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.patience",
#                                                                "default": 10,
#                                                                "name": {
#                                                                   "cn": "Patience",
#                                                                   "en": "Patience"
#                                                                },
#                                                                "type": "int"
#                                                             }
#                                                          ],
#                                                          "type": "H"
#                                                       },
#                                                       "value": "reduce_on_plateau"
#                                                    },
#                                                    {
#                                                       "name": {
#                                                          "cn": "StepLR",
#                                                          "en": "StepLR"
#                                                       },
#                                                       "trigger": {
#                                                          "objs": [
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.step_size",
#                                                                "default": 30,
#                                                                "name": {
#                                                                   "cn": "Step Size",
#                                                                   "en": "Step Size"
#                                                                },
#                                                                "tips": "Period of learning rate decay",
#                                                                "type": "int"
#                                                             },
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.gamma",
#                                                                "default": 0.10000000000000001,
#                                                                "name": {
#                                                                   "cn": "Gamma",
#                                                                   "en": "Gamma"
#                                                                },
#                                                                "tips": "Multiplicative factor of learning rate decay",
#                                                                "type": "float"
#                                                             }
#                                                          ],
#                                                          "type": "H"
#                                                       },
#                                                       "value": "step"
#                                                    },
#                                                    {
#                                                       "name": {
#                                                          "cn": "MultiStepLR",
#                                                          "en": "MultiStepLR"
#                                                       },
#                                                       "trigger": {
#                                                          "objs": [
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.milestones",
#                                                                "default": [
#                                                                   30,
#                                                                   80
#                                                                ],
#                                                                "name": {
#                                                                   "cn": "Milestones",
#                                                                   "en": "Milestones"
#                                                                },
#                                                                "tips": "List of epoch indices",
#                                                                "type": "int-array"
#                                                             },
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.gamma",
#                                                                "default": 0.10000000000000001,
#                                                                "name": {
#                                                                   "cn": "Gamma",
#                                                                   "en": "Gamma"
#                                                                },
#                                                                "tips": "Multiplicative factor of learning rate decay",
#                                                                "type": "float"
#                                                             }
#                                                          ],
#                                                          "type": "H"
#                                                       },
#                                                       "value": "multi_step"
#                                                    },
#                                                    {
#                                                       "name": {
#                                                          "cn": "ExponentialLR",
#                                                          "en": "ExponentialLR"
#                                                       },
#                                                       "trigger": {
#                                                          "objs": [
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.gamma",
#                                                                "default": 0.10000000000000001,
#                                                                "name": {
#                                                                   "cn": "Gamma",
#                                                                   "en": "Gamma"
#                                                                },
#                                                                "tips": "Multiplicative factor of learning rate decay",
#                                                                "type": "float"
#                                                             }
#                                                          ],
#                                                          "type": "H"
#                                                       },
#                                                       "value": "exponential"
#                                                    }
#                                                 ],
#                                                 "type": "string-enum-trigger"
#                                              }
#                                           ]
#                                        },
#                                        "value": true
#                                     },
#                                     {
#                                        "trigger": { },
#                                        "value": false
#                                     }
#                                  ],
#                                  "type": "bool-trigger"
#                               }
#                            ]
#                         }
#                      ],
#                      "type": "accordion"
#                   }
#                ]
#             }
#          ],
#          "type": "tab"
#       },
#       {
#          "name": {
#             "cn": "调试输出: ",
#             "en": "Debug Output"
#          },
#          "objs": [ ],
#          "type": "output"
#       }
#    ],
#    "type": "page"
# }

# %% [markdown]
# ## 5. Get NLP Schema Json

# %%
result = requests.post(
    url='http://116.85.5.40:8119/k12ai/framework/schema', 
    json={'file': 'k12ai_nlp.jsonnet'}).text
print(result)
# Out:
# {
#    "objs": [
#       {
#          "objs": [
#             {
#                "name": {
#                   "cn": "Data",
#                   "en": "Data"
#                },
#                "objs": [
#                   {
#                      "_id_": "_k12.dataset",
#                      "default": "sst",
#                      "name": {
#                         "cn": "Dataset Name",
#                         "en": "Dataset Name"
#                      },
#                      "readonly": true,
#                      "type": "string"
#                   },
#                   {
#                      "objs": [
#                         {
#                            "name": {
#                               "cn": "Reader",
#                               "en": "Reader"
#                            },
#                            "objs": [
#                               {
#                                  "name": {
#                                     "cn": "Phase",
#                                     "en": "Phase"
#                                  },
#                                  "objs": [
#                                     {
#                                        "name": {
#                                           "cn": "Train",
#                                           "en": "Train"
#                                        },
#                                        "objs": [
#                                           {
#                                              "_id_": "dataset_name_reader.type",
#                                              "default": "sst_tokens",
#                                              "name": {
#                                                 "cn": "Type",
#                                                 "en": "Type"
#                                              },
#                                              "objs": [
#                                                 {
#                                                    "name": {
#                                                       "cn": "SST Tokens",
#                                                       "en": "SST Tokens"
#                                                    },
#                                                    "trigger": {
#                                                       "objs": [
#                                                          {
#                                                             "objs": [
#                                                                {
#                                                                   "_id_": "dataset_name_reader.layz",
#                                                                   "default": true,
#                                                                   "name": {
#                                                                      "cn": "lazy",
#                                                                      "en": "lazy"
#                                                                   },
#                                                                   "type": "bool"
#                                                                },
#                                                                {
#                                                                   "_id_": "dataset_name_reader.use_subtrees",
#                                                                   "default": false,
#                                                                   "name": {
#                                                                      "cn": "use subtrees",
#                                                                      "en": "use subtrees"
#                                                                   },
#                                                                   "type": "bool"
#                                                                },
#                                                                {
#                                                                   "_id_": "dataset_name_reader.granularity",
#                                                                   "default": "5-class",
#                                                                   "name": {
#                                                                      "cn": "granularity",
#                                                                      "en": "granularity"
#                                                                   },
#                                                                   "type": "string"
#                                                                }
#                                                             ],
#                                                             "type": "H"
#                                                          },
#                                                          {
#                                                             "_id_": "_k12.token_indexers.single_id",
#                                                             "default": false,
#                                                             "name": {
#                                                                "cn": "single_id",
#                                                                "en": "single_id"
#                                                             },
#                                                             "objs": [
#                                                                {
#                                                                   "trigger": {
#                                                                      "objs": [
#                                                                         {
#                                                                            "objs": [
#                                                                               {
#                                                                                  "_id_": "dataset_name_readertoken_indexers.tokens.type",
#                                                                                  "default": "single_id",
#                                                                                  "name": {
#                                                                                     "cn": "type",
#                                                                                     "en": "type"
#                                                                                  },
#                                                                                  "readonly": true,
#                                                                                  "type": "string"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "dataset_name_readertoken_indexers.tokens.lowercase_tokens",
#                                                                                  "default": false,
#                                                                                  "name": {
#                                                                                     "cn": "lowercase",
#                                                                                     "en": "lowercase"
#                                                                                  },
#                                                                                  "type": "bool"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "dataset_name_readertoken_indexers.tokens.token_min_padding_length",
#                                                                                  "default": 0,
#                                                                                  "name": {
#                                                                                     "cn": "min padding length",
#                                                                                     "en": "min padding length"
#                                                                                  },
#                                                                                  "type": "int"
#                                                                               }
#                                                                            ],
#                                                                            "type": "H"
#                                                                         }
#                                                                      ]
#                                                                   },
#                                                                   "value": true
#                                                                },
#                                                                {
#                                                                   "trigger": { },
#                                                                   "value": false
#                                                                }
#                                                             ],
#                                                             "type": "bool-trigger"
#                                                          }
#                                                       ]
#                                                    },
#                                                    "value": "sst_tokens"
#                                                 }
#                                              ],
#                                              "type": "string-enum-trigger"
#                                           }
#                                        ]
#                                     },
#                                     {
#                                        "name": {
#                                           "cn": "Validation",
#                                           "en": "Validation"
#                                        },
#                                        "objs": [
#                                           {
#                                              "_id_": "_k12.validation_dataset_name_reader.bool",
#                                              "default": false,
#                                              "name": {
#                                                 "cn": "Enable",
#                                                 "en": "Enable"
#                                              },
#                                              "objs": [
#                                                 {
#                                                    "trigger": {
#                                                       "objs": [
#                                                          {
#                                                             "_id_": "validation_dataset_name_reader.type",
#                                                             "default": "sst_tokens",
#                                                             "name": {
#                                                                "cn": "Type",
#                                                                "en": "Type"
#                                                             },
#                                                             "objs": [
#                                                                {
#                                                                   "name": {
#                                                                      "cn": "SST Tokens",
#                                                                      "en": "SST Tokens"
#                                                                   },
#                                                                   "trigger": {
#                                                                      "objs": [
#                                                                         {
#                                                                            "objs": [
#                                                                               {
#                                                                                  "_id_": "validation_dataset_name_reader.layz",
#                                                                                  "default": true,
#                                                                                  "name": {
#                                                                                     "cn": "lazy",
#                                                                                     "en": "lazy"
#                                                                                  },
#                                                                                  "type": "bool"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_dataset_name_reader.use_subtrees",
#                                                                                  "default": false,
#                                                                                  "name": {
#                                                                                     "cn": "use subtrees",
#                                                                                     "en": "use subtrees"
#                                                                                  },
#                                                                                  "type": "bool"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_dataset_name_reader.granularity",
#                                                                                  "default": "5-class",
#                                                                                  "name": {
#                                                                                     "cn": "granularity",
#                                                                                     "en": "granularity"
#                                                                                  },
#                                                                                  "type": "string"
#                                                                               }
#                                                                            ],
#                                                                            "type": "H"
#                                                                         },
#                                                                         {
#                                                                            "_id_": "_k12.token_indexers.single_id",
#                                                                            "default": false,
#                                                                            "name": {
#                                                                               "cn": "single_id",
#                                                                               "en": "single_id"
#                                                                            },
#                                                                            "objs": [
#                                                                               {
#                                                                                  "trigger": {
#                                                                                     "objs": [
#                                                                                        {
#                                                                                           "objs": [
#                                                                                              {
#                                                                                                 "_id_": "validation_dataset_name_readertoken_indexers.tokens.type",
#                                                                                                 "default": "single_id",
#                                                                                                 "name": {
#                                                                                                    "cn": "type",
#                                                                                                    "en": "type"
#                                                                                                 },
#                                                                                                 "readonly": true,
#                                                                                                 "type": "string"
#                                                                                              },
#                                                                                              {
#                                                                                                 "_id_": "validation_dataset_name_readertoken_indexers.tokens.lowercase_tokens",
#                                                                                                 "default": false,
#                                                                                                 "name": {
#                                                                                                    "cn": "lowercase",
#                                                                                                    "en": "lowercase"
#                                                                                                 },
#                                                                                                 "type": "bool"
#                                                                                              },
#                                                                                              {
#                                                                                                 "_id_": "validation_dataset_name_readertoken_indexers.tokens.token_min_padding_length",
#                                                                                                 "default": 0,
#                                                                                                 "name": {
#                                                                                                    "cn": "min padding length",
#                                                                                                    "en": "min padding length"
#                                                                                                 },
#                                                                                                 "type": "int"
#                                                                                              }
#                                                                                           ],
#                                                                                           "type": "H"
#                                                                                        }
#                                                                                     ]
#                                                                                  },
#                                                                                  "value": true
#                                                                               },
#                                                                               {
#                                                                                  "trigger": { },
#                                                                                  "value": false
#                                                                               }
#                                                                            ],
#                                                                            "type": "bool-trigger"
#                                                                         }
#                                                                      ]
#                                                                   },
#                                                                   "value": "sst_tokens"
#                                                                }
#                                                             ],
#                                                             "type": "string-enum-trigger"
#                                                          }
#                                                       ]
#                                                    },
#                                                    "value": true
#                                                 },
#                                                 {
#                                                    "trigger": { },
#                                                    "value": false
#                                                 }
#                                              ],
#                                              "type": "bool-trigger"
#                                           }
#                                        ]
#                                     }
#                                  ],
#                                  "type": "navigation"
#                               }
#                            ]
#                         },
#                         {
#                            "name": {
#                               "cn": "Iterator",
#                               "en": "Iterator"
#                            },
#                            "objs": [
#                               {
#                                  "name": {
#                                     "cn": "Phase",
#                                     "en": "Phase"
#                                  },
#                                  "objs": [
#                                     {
#                                        "name": {
#                                           "cn": "Train",
#                                           "en": "Train"
#                                        },
#                                        "objs": [
#                                           {
#                                              "_id_": "iterator.type",
#                                              "default": "bucket",
#                                              "name": {
#                                                 "cn": "Iterator Type",
#                                                 "en": "Iterator Type"
#                                              },
#                                              "objs": [
#                                                 {
#                                                    "name": {
#                                                       "cn": "bucket",
#                                                       "en": "bucket"
#                                                    },
#                                                    "trigger": {
#                                                       "objs": [
#                                                          {
#                                                             "objs": [
#                                                                {
#                                                                   "_id_": "iterator.batch_size",
#                                                                   "default": 32,
#                                                                   "min": 8,
#                                                                   "name": {
#                                                                      "cn": "batch size",
#                                                                      "en": "batch size"
#                                                                   },
#                                                                   "type": "int"
#                                                                },
#                                                                {
#                                                                   "_id_": "iterator.instances_per_epoch",
#                                                                   "default": 32,
#                                                                   "min": 8,
#                                                                   "name": {
#                                                                      "cn": "instance per epoch",
#                                                                      "en": "instance per epoch"
#                                                                   },
#                                                                   "type": "int"
#                                                                },
#                                                                {
#                                                                   "_id_": "iterator.max_instances_in_memory",
#                                                                   "default": 32,
#                                                                   "min": 8,
#                                                                   "name": {
#                                                                      "cn": "max instance",
#                                                                      "en": "max instance"
#                                                                   },
#                                                                   "type": "int"
#                                                                },
#                                                                {
#                                                                   "_id_": "iterator.cache_instances",
#                                                                   "default": false,
#                                                                   "name": {
#                                                                      "cn": "cache instances",
#                                                                      "en": "cache instances"
#                                                                   },
#                                                                   "type": "bool"
#                                                                },
#                                                                {
#                                                                   "_id_": "iterator.track_epoch",
#                                                                   "default": false,
#                                                                   "name": {
#                                                                      "cn": "track epoch",
#                                                                      "en": "track epoch"
#                                                                   },
#                                                                   "type": "bool"
#                                                                }
#                                                             ],
#                                                             "type": "H"
#                                                          },
#                                                          {
#                                                             "objs": [
#                                                                {
#                                                                   "_id_": "iterator.sorting_keys",
#                                                                   "default": [
#                                                                      [
#                                                                         "tokens",
#                                                                         "num_tokens"
#                                                                      ]
#                                                                   ],
#                                                                   "name": {
#                                                                      "cn": "sorting keys",
#                                                                      "en": "sorting keys"
#                                                                   },
#                                                                   "readonly": true,
#                                                                   "type": "string-array",
#                                                                   "width": 600
#                                                                },
#                                                                {
#                                                                   "_id_": "iterator.padding_noise",
#                                                                   "default": 0.10000000000000001,
#                                                                   "name": {
#                                                                      "cn": "padding noise",
#                                                                      "en": "padding noise"
#                                                                   },
#                                                                   "type": "float"
#                                                                },
#                                                                {
#                                                                   "_id_": "iterator.biggest_batch_first",
#                                                                   "default": false,
#                                                                   "name": {
#                                                                      "cn": "biggest batch first",
#                                                                      "en": "biggest batch first"
#                                                                   },
#                                                                   "type": "bool"
#                                                                },
#                                                                {
#                                                                   "_id_": "iterator.skip_smaller_batches",
#                                                                   "default": false,
#                                                                   "name": {
#                                                                      "cn": "skip smaller batches",
#                                                                      "en": "skip smaller batches"
#                                                                   },
#                                                                   "type": "bool"
#                                                                }
#                                                             ],
#                                                             "type": "H"
#                                                          }
#                                                       ]
#                                                    },
#                                                    "value": "bucket"
#                                                 },
#                                                 {
#                                                    "name": {
#                                                       "cn": "basic",
#                                                       "en": "basic"
#                                                    },
#                                                    "trigger": {
#                                                       "objs": [
#                                                          {
#                                                             "_id_": "iterator.batch_size",
#                                                             "default": 32,
#                                                             "min": 8,
#                                                             "name": {
#                                                                "cn": "batch size",
#                                                                "en": "batch size"
#                                                             },
#                                                             "type": "int"
#                                                          },
#                                                          {
#                                                             "_id_": "iterator.instances_per_epoch",
#                                                             "default": 32,
#                                                             "min": 8,
#                                                             "name": {
#                                                                "cn": "instance per epoch",
#                                                                "en": "instance per epoch"
#                                                             },
#                                                             "type": "int"
#                                                          },
#                                                          {
#                                                             "_id_": "iterator.max_instances_in_memory",
#                                                             "default": 32,
#                                                             "min": 8,
#                                                             "name": {
#                                                                "cn": "max instance",
#                                                                "en": "max instance"
#                                                             },
#                                                             "type": "int"
#                                                          },
#                                                          {
#                                                             "_id_": "iterator.cache_instances",
#                                                             "default": false,
#                                                             "name": {
#                                                                "cn": "cache instances",
#                                                                "en": "cache instances"
#                                                             },
#                                                             "type": "bool"
#                                                          },
#                                                          {
#                                                             "_id_": "iterator.track_epoch",
#                                                             "default": false,
#                                                             "name": {
#                                                                "cn": "track epoch",
#                                                                "en": "track epoch"
#                                                             },
#                                                             "type": "bool"
#                                                          }
#                                                       ],
#                                                       "type": "H"
#                                                    },
#                                                    "value": "basic"
#                                                 }
#                                              ],
#                                              "type": "string-enum-trigger"
#                                           }
#                                        ]
#                                     },
#                                     {
#                                        "name": {
#                                           "cn": "Validation",
#                                           "en": "Validation"
#                                        },
#                                        "objs": [
#                                           {
#                                              "_id_": "_k12.validation_iterator.bool",
#                                              "default": false,
#                                              "name": {
#                                                 "cn": "Enable",
#                                                 "en": "Enable"
#                                              },
#                                              "objs": [
#                                                 {
#                                                    "trigger": {
#                                                       "objs": [
#                                                          {
#                                                             "_id_": "validation_iterator.type",
#                                                             "default": "bucket",
#                                                             "name": {
#                                                                "cn": "Iterator Type",
#                                                                "en": "Iterator Type"
#                                                             },
#                                                             "objs": [
#                                                                {
#                                                                   "name": {
#                                                                      "cn": "bucket",
#                                                                      "en": "bucket"
#                                                                   },
#                                                                   "trigger": {
#                                                                      "objs": [
#                                                                         {
#                                                                            "objs": [
#                                                                               {
#                                                                                  "_id_": "validation_iterator.batch_size",
#                                                                                  "default": 32,
#                                                                                  "min": 8,
#                                                                                  "name": {
#                                                                                     "cn": "batch size",
#                                                                                     "en": "batch size"
#                                                                                  },
#                                                                                  "type": "int"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_iterator.instances_per_epoch",
#                                                                                  "default": 32,
#                                                                                  "min": 8,
#                                                                                  "name": {
#                                                                                     "cn": "instance per epoch",
#                                                                                     "en": "instance per epoch"
#                                                                                  },
#                                                                                  "type": "int"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_iterator.max_instances_in_memory",
#                                                                                  "default": 32,
#                                                                                  "min": 8,
#                                                                                  "name": {
#                                                                                     "cn": "max instance",
#                                                                                     "en": "max instance"
#                                                                                  },
#                                                                                  "type": "int"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_iterator.cache_instances",
#                                                                                  "default": false,
#                                                                                  "name": {
#                                                                                     "cn": "cache instances",
#                                                                                     "en": "cache instances"
#                                                                                  },
#                                                                                  "type": "bool"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_iterator.track_epoch",
#                                                                                  "default": false,
#                                                                                  "name": {
#                                                                                     "cn": "track epoch",
#                                                                                     "en": "track epoch"
#                                                                                  },
#                                                                                  "type": "bool"
#                                                                               }
#                                                                            ],
#                                                                            "type": "H"
#                                                                         },
#                                                                         {
#                                                                            "objs": [
#                                                                               {
#                                                                                  "_id_": "validation_iterator.sorting_keys",
#                                                                                  "default": [
#                                                                                     [
#                                                                                        "tokens",
#                                                                                        "num_tokens"
#                                                                                     ]
#                                                                                  ],
#                                                                                  "name": {
#                                                                                     "cn": "sorting keys",
#                                                                                     "en": "sorting keys"
#                                                                                  },
#                                                                                  "readonly": true,
#                                                                                  "type": "string-array",
#                                                                                  "width": 600
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_iterator.padding_noise",
#                                                                                  "default": 0.10000000000000001,
#                                                                                  "name": {
#                                                                                     "cn": "padding noise",
#                                                                                     "en": "padding noise"
#                                                                                  },
#                                                                                  "type": "float"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_iterator.biggest_batch_first",
#                                                                                  "default": false,
#                                                                                  "name": {
#                                                                                     "cn": "biggest batch first",
#                                                                                     "en": "biggest batch first"
#                                                                                  },
#                                                                                  "type": "bool"
#                                                                               },
#                                                                               {
#                                                                                  "_id_": "validation_iterator.skip_smaller_batches",
#                                                                                  "default": false,
#                                                                                  "name": {
#                                                                                     "cn": "skip smaller batches",
#                                                                                     "en": "skip smaller batches"
#                                                                                  },
#                                                                                  "type": "bool"
# ...
#                                                 },
#                                                 "type": "float"
#                                              }
#                                           ],
#                                           "type": "H"
#                                        },
#                                        "value": "adam"
#                                     },
#                                     {
#                                        "name": {
#                                           "cn": "sgd",
#                                           "en": "sgd"
#                                        },
#                                        "trigger": {
#                                           "objs": [
#                                              {
#                                                 "_id_": "trainer.optimizer.momentum",
#                                                 "default": 0,
#                                                 "name": {
#                                                    "cn": "Momentum",
#                                                    "en": "Momentum"
#                                                 },
#                                                 "type": "float"
#                                              },
#                                              {
#                                                 "_id_": "trainer.optimizer.lr",
#                                                 "default": 0.001,
#                                                 "name": {
#                                                    "cn": "LR",
#                                                    "en": "LR"
#                                                 },
#                                                 "type": "float"
#                                              },
#                                              {
#                                                 "_id_": "trainer.optimizer.weight_decay",
#                                                 "default": 0,
#                                                 "name": {
#                                                    "cn": "Weight Decay",
#                                                    "en": "Weight Decay"
#                                                 },
#                                                 "type": "float"
#                                              }
#                                           ],
#                                           "type": "H"
#                                        },
#                                        "value": "sgd"
#                                     }
#                                  ],
#                                  "type": "string-enum-trigger"
#                               }
#                            ]
#                         },
#                         {
#                            "name": {
#                               "cn": "LR Scheduler",
#                               "en": "LR Scheduler"
#                            },
#                            "objs": [
#                               {
#                                  "_id_": "_k12.lr_scheduler.bool",
#                                  "default": true,
#                                  "name": {
#                                     "cn": "Enable",
#                                     "en": "Enable"
#                                  },
#                                  "objs": [
#                                     {
#                                        "trigger": {
#                                           "objs": [
#                                              {
#                                                 "_id_": "trainer.learning_rate_scheduler.type",
#                                                 "default": "reduce_on_plateau",
#                                                 "name": {
#                                                    "cn": "LR Scheduler Type",
#                                                    "en": "LR Scheduler Type"
#                                                 },
#                                                 "objs": [
#                                                    {
#                                                       "name": {
#                                                          "cn": "ReduceLROnPlateau",
#                                                          "en": "ReduceLROnPlateau"
#                                                       },
#                                                       "trigger": {
#                                                          "objs": [
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.mode",
#                                                                "default": "min",
#                                                                "name": {
#                                                                   "cn": "Mode",
#                                                                   "en": "Mode"
#                                                                },
#                                                                "objs": [
#                                                                   {
#                                                                      "name": {
#                                                                         "cn": "min",
#                                                                         "en": "min"
#                                                                      },
#                                                                      "value": "min"
#                                                                   },
#                                                                   {
#                                                                      "name": {
#                                                                         "cn": "max",
#                                                                         "en": "max"
#                                                                      },
#                                                                      "value": "max"
#                                                                   }
#                                                                ],
#                                                                "type": "string-enum"
#                                                             },
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.factor",
#                                                                "default": 0.10000000000000001,
#                                                                "name": {
#                                                                   "cn": "Factor",
#                                                                   "en": "Factor"
#                                                                },
#                                                                "type": "float"
#                                                             },
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.patience",
#                                                                "default": 10,
#                                                                "name": {
#                                                                   "cn": "Patience",
#                                                                   "en": "Patience"
#                                                                },
#                                                                "type": "int"
#                                                             }
#                                                          ],
#                                                          "type": "H"
#                                                       },
#                                                       "value": "reduce_on_plateau"
#                                                    },
#                                                    {
#                                                       "name": {
#                                                          "cn": "StepLR",
#                                                          "en": "StepLR"
#                                                       },
#                                                       "trigger": {
#                                                          "objs": [
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.step_size",
#                                                                "default": 30,
#                                                                "name": {
#                                                                   "cn": "Step Size",
#                                                                   "en": "Step Size"
#                                                                },
#                                                                "tips": "Period of learning rate decay",
#                                                                "type": "int"
#                                                             },
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.gamma",
#                                                                "default": 0.10000000000000001,
#                                                                "name": {
#                                                                   "cn": "Gamma",
#                                                                   "en": "Gamma"
#                                                                },
#                                                                "tips": "Multiplicative factor of learning rate decay",
#                                                                "type": "float"
#                                                             }
#                                                          ],
#                                                          "type": "H"
#                                                       },
#                                                       "value": "step"
#                                                    },
#                                                    {
#                                                       "name": {
#                                                          "cn": "MultiStepLR",
#                                                          "en": "MultiStepLR"
#                                                       },
#                                                       "trigger": {
#                                                          "objs": [
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.milestones",
#                                                                "default": [
#                                                                   30,
#                                                                   80
#                                                                ],
#                                                                "name": {
#                                                                   "cn": "Milestones",
#                                                                   "en": "Milestones"
#                                                                },
#                                                                "tips": "List of epoch indices",
#                                                                "type": "int-array"
#                                                             },
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.gamma",
#                                                                "default": 0.10000000000000001,
#                                                                "name": {
#                                                                   "cn": "Gamma",
#                                                                   "en": "Gamma"
#                                                                },
#                                                                "tips": "Multiplicative factor of learning rate decay",
#                                                                "type": "float"
#                                                             }
#                                                          ],
#                                                          "type": "H"
#                                                       },
#                                                       "value": "multi_step"
#                                                    },
#                                                    {
#                                                       "name": {
#                                                          "cn": "ExponentialLR",
#                                                          "en": "ExponentialLR"
#                                                       },
#                                                       "trigger": {
#                                                          "objs": [
#                                                             {
#                                                                "_id_": "trainer.learning_rate_scheduler.gamma",
#                                                                "default": 0.10000000000000001,
#                                                                "name": {
#                                                                   "cn": "Gamma",
#                                                                   "en": "Gamma"
#                                                                },
#                                                                "tips": "Multiplicative factor of learning rate decay",
#                                                                "type": "float"
#                                                             }
#                                                          ],
#                                                          "type": "H"
#                                                       },
#                                                       "value": "exponential"
#                                                    }
#                                                 ],
#                                                 "type": "string-enum-trigger"
#                                              }
#                                           ]
#                                        },
#                                        "value": true
#                                     },
#                                     {
#                                        "trigger": { },
#                                        "value": false
#                                     }
#                                  ],
#                                  "type": "bool-trigger"
#                               }
#                            ]
#                         }
#                      ],
#                      "type": "accordion"
#                   }
#                ]
#             }
#          ],
#          "type": "tab"
#       },
#       {
#          "name": {
#             "cn": "调试输出: ",
#             "en": "Debug Output"
#          },
#          "objs": [ ],
#          "type": "output"
#       }
#    ],
#    "type": "page"
# }
