# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from k12libs.utils.nb_easy import k12ai_start_html, k12ai_get_top_dir
import os
import PIL.Image as Image
import base64
import io
import json
import requests
from urllib.parse import urlencode

# %%
# default_test_pic = os.path.join(k12ai_get_top_dir(), 'assets', 'images', 'test-car_lp-1.jpeg')
# default_test_pic = os.path.join(k12ai_get_top_dir(), 'assets', 'images', 'test-car_lp-2.jpg')
default_test_pic = os.path.join(k12ai_get_top_dir(), 'assets', 'images', 'test-car_lp-3.jpeg')

# %% [markdown]
# ## 默认测试图片

# %%
img = Image.open(default_test_pic)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x434 at 0x7F9235EE5AC8>

# %% [markdown]
# ## Base64

# %%
with open(default_test_pic, 'rb') as fr:
    b4data = base64.b64encode(fr.read()).decode()
    
params = {
    'default': b4data
}

# %% [markdown]
# ## 脸部探测

# %% [markdown]
# ### 方式一:API调用(/colorai/licenseplate_detection)

# %%
host = '116.85.54.39'
port = 8189

# API
uri = f'http://{host}:{port}/colorai/licenseplate_detection'

# 输入:
reqdata = {
    'orig_img': 'data:image/jpeg;base64,' + b4data
}

resdata = json.loads(requests.post(url=uri, json=reqdata).text)
# 输出:
# {
#     code: '100200' # ok
#     content: {'predict': 'data:image/png;base64,' + base64str}
# }

if '100200' == resdata['code']:
    result = resdata['content']
else:
    # error:
    print(resdata)
    raise
    
picbytes = base64.b64decode(result['predict'].split(',')[1])
Image.open(io.BytesIO(picbytes))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=580x434 at 0x7F92A0A18C50>

# %% [markdown]
# ### 方式二:页面调试(点击后大概5秒出结果)

# %%
k12ai_start_html(f'predict.html?{urlencode(params)}', height=900, flask=True)
# Out:
# <style>.container { width:95% !important; }</style>
#  * Serving Flask app "k12libs.utils.nb_easy" (lazy loading)
#         <iframe
#             width="100%"
#             height="900"
#             src="http://116.85.5.40:9091/predict.html?default=%2F9j%2F4AAQSkZJRgABAQEASABIAAD%2F2wBDAA4KCwwLCQ4MCwwQDw4RFSMXFRMTFSsfIRojMy02NTItMTA4P1FFODxNPTAxRmBHTVRWW1xbN0RjamNYalFZW1f%2F2wBDAQ8QEBUSFSkXFylXOjE6V1dXV1dXV1dXV1dXV1dXV1dXV1dXV1dXV1dXV1dXV1dXV1dXV1dXV1dXV1dXV1dXV1f%2FwAARCAGyAkQDASIAAhEBAxEB%2F8QAGwAAAQUBAQAAAAAAAAAAAAAAAgABAwQFBgf%2FxABJEAEAAQMCBAMGAwUHAQYFBAMBAgADEQQhBRIxQVFhcQYTgZGhsRQiwSMyQnLRFSQzNFLh8GIWQ3OCkvElNVNjgwcmRaJUk7L%2FxAAZAQEBAQEBAQAAAAAAAAAAAAAAAQIDBAX%2FxAAlEQEBAQEAAgIDAQEAAgMAAAAAARECAyESMRNBUQQiMmEUM4H%2F2gAMAwEAAhEDEQA%2FAOMlC7bhDnGJPKKY2E6eXT50iEgVmL5PWrMm06WVvUNxmGLYOQz03z0NwwbnpVaykP35GxgwVyYSwm8u0M%2BtRyuYcIPrTTvZjIDKGMLtjxPOgik8j8EOlJBYixYqCHg75f0KVwlL8khM9MuT5VFG8wMDk7KUws0EQdxe%2FwDtVwO25gsUTOclRyZS2uKh0z2qUnKEOjju9qm07GeW5AQ364xVA